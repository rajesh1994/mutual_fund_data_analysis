# %%
import re
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
# Reading elss mutual funds csv file
elss_mf = pd.read_csv('elss_mf_data(10-May-2021 18:19:46).csv')

# %%
# Extracting a plan from "Scheme Name" column
scheme_name = list(elss_mf['Scheme Name'])
plan = []
for i in scheme_name:
    #print(type(i))
    plan.append(re.findall("Direct|Regular", str(i)))
#plan
for p in plan:
    if len(p) == 0:
        #print(type(p))
        p.append("Regular")
elss_mf['Plan'] = plan

# %%
# Extracting a category from "Scheme Name" column
scheme_name = list(elss_mf['Scheme Name'])
category = []
for i in scheme_name:
    #print(type(i))
    category.append(re.findall("ELSS", str(i)))
elss_mf['Category'] = category

# %%
# Modifiying 'Scheme Name' column
elss_mf['Scheme Name'] = elss_mf['Scheme Name'].str.rstrip(' - GrowthELSS')

# %%
#Replacing "']" & "['" string with "" in Plan columns
elss_mf['Plan'] = elss_mf['Plan'].astype(str).str.replace("\['","", regex=True)
elss_mf['Plan'] = elss_mf['Plan'].astype(str).str.replace("']","", regex=True)

#Replacing "']" & "['" string with "" in Category columns
elss_mf['Category'] = elss_mf['Category'].astype(str).str.replace("\['","", regex=True)
elss_mf['Category'] = elss_mf['Category'].astype(str).str.replace("']","", regex=True)

# %%
#Replacing "ELSS', 'ELSS" string with "ELSS" in Category columns
elss_mf['Category'] = elss_mf['Category'].astype(str).str.replace("ELSS', 'ELSS","ELSS", regex=True)

#Replacing "%" string with "" in Crisil Rank, % Debt Holding, No of instruments in portfolio,
# % MF Holding, % Other Holding, Turnover ratio, MTD, 10Y_SIP_RTN(%) & 5Y_SIP_RTN(%) columns
elss_mf[['% Debt Holding', 'No of instruments in portfolio',
          '% MF Holding', '% Other Holding', 'Turnover ratio(%)',
          'MTD', '10Y_SIP_RTN(%)', '5Y_SIP_RTN(%)'         
         ]] = elss_mf[['% Debt Holding', 'No of instruments in portfolio',
                        '% MF Holding', '% Other Holding', 'Turnover ratio(%)',
                        'MTD', '10Y_SIP_RTN(%)', '5Y_SIP_RTN(%)'
                        ]].replace("%", "", regex=True)

#Replacing "-" string with "0" in Crisil Rank columns
elss_mf['Crisil Rank'] = elss_mf['Crisil Rank'].replace("-", "", regex=True)

# %%
#Replacing "-" string with "0" in Crisil Rank columns
elss_mf['Crisil Rank'] = elss_mf['Crisil Rank'].replace("", "0", regex=True)

#Replacing "%" with '' in the column
elss_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
         '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)', '2018_RTN(%)',
         '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)", "2012_RTN(%)", "2011_RTN(%)",
         "2010_RTN(%)", '% Equity Holding', '% Debt Holding', '% MF Holding', '% Cash Holding', '% Other Holding',
         '1D Change(%)', '1Y_SIP_RTN(%)', '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)',
         "Apr'21", "Mar'21", "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20",
         "Jul'20", "Jun'20", "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19",
         "Q2'19", "Q1'19", "Q4'18", "Q3'18", "YTD", "MTD", "Turnover ratio(%)"
         ]] = elss_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
                       '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)',
                       '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)",
                       "2012_RTN(%)", "2011_RTN(%)", "2010_RTN(%)", '% Equity Holding', '% Debt Holding',
                       '% MF Holding', '% Cash Holding', '% Other Holding', '1D Change(%)', '1Y_SIP_RTN(%)',
                       '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)', "Apr'21", "Mar'21",
                       "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20", "Jul'20", "Jun'20",
                       "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19", "Q2'19", "Q1'19",
                       "Q4'18", "Q3'18", "YTD",'MTD', "Turnover ratio(%)"
                       ]].replace("%", "", regex=True)
print("Shape of the dataframe:", elss_mf.shape)
elss_mf.head()
# Out:
# Shape of the dataframe: (128, 86)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0                       Quant Tax Plan - Direct Plan           5    106.05
# 1                                     Quant Tax Plan           5    106.05
# 2  Sundaram Long Term Micro Cap Tax Advantage Fun...           0     37.10
# 3  Sundaram Long Term Micro Cap Tax Advantage Fun...           0     37.10
# 4  Sundaram Long Term Micro Cap Tax Advantage Fun...           0     38.37
#
#   1W_RTN(%) 1M_RTN(%) 3M_RTN(%) 6M_RTN(%) YTD_RTN(%) 1Y_RTN(%) 2Y_RTN(%)  ...  \
# 0      6.05     10.05     24.16     55.08      32.23    131.26     43.55  ...
# 1      6.00      9.87     23.50     53.42      31.24    126.70     41.01  ...
# 2      4.12      6.74     16.47     50.65      23.93    104.47     15.92  ...
# 3      4.11      6.72     16.40     50.42      23.81    103.83     15.56  ...
# 4      3.90      7.10     16.99     50.67      24.66    105.11     14.93  ...
#
#   52WH as on   52W Low 52WL as on 1Y_SIP_RTN(%) 2Y_SIP_RTN(%) 3Y_SIP_RTN(%)  \
# 0  03-Mar-21  308.8600  18-May-20         59.12         84.32         92.16
# 1  03-Mar-21  424.6445  18-May-20         57.16         80.35         86.86
# 2  03-Mar-21  288.1000  18-May-20         47.25         49.68         41.15
# 3  03-Mar-21  397.6326  18-May-20         47.25         48.62         39.60
# 4  07-May-21   81.3329  18-May-20         47.01         48.19         38.75
#
#   5Y_SIP_RTN(%) 10Y_SIP_RTN(%)     Plan Category
# 0        109.87              -   Direct     ELSS
# 1        102.63         218.21  Regular     ELSS
# 2             -              -   Direct     ELSS
# 3             -              -  Regular     ELSS
# 4             -              -   Direct     ELSS
#
# [5 rows x 86 columns]

# %%
#Sorting a elss_mf dataframe by "Crisil Rank Column"
elss_mf.sort_values(by=['Crisil Rank', 'Scheme Name', 'AuM (Cr)'], inplace=True, ascending=False)
print("Shape of the dataframe:", elss_mf.shape)
elss_mf.head()
# Out:
# Shape of the dataframe: (128, 86)
#                                       Scheme Name Crisil Rank  AuM (Cr)  \
# 0                    Quant Tax Plan - Direct Plan           5    106.05
# 1                                  Quant Tax Plan           5    106.05
# 31      Mirae Asset Tax Saver Fund - Regular Plan           5   6934.49
# 30       Mirae Asset Tax Saver Fund - Direct Plan           5   6934.49
# 65  Canara Robeco Equity Tax Saver - Regular Plan           5   2044.06
#
#    1W_RTN(%) 1M_RTN(%) 3M_RTN(%) 6M_RTN(%) YTD_RTN(%) 1Y_RTN(%) 2Y_RTN(%)  \
# 0       6.05     10.05     24.16     55.08      32.23    131.26     43.55
# 1       6.00      9.87     23.50     53.42      31.24    126.70     41.01
# 31      1.92      1.46      3.84     27.38      12.70     76.36     22.74
# 30      1.94      1.57      4.22     28.35      13.29     79.05     24.68
# 65      1.22      0.82      0.42     24.71      10.16     64.73     22.47
#
#     ... 52WH as on   52W Low 52WL as on 1Y_SIP_RTN(%) 2Y_SIP_RTN(%)  \
# 0   ...  03-Mar-21  308.8600  18-May-20         59.12         84.32
# 1   ...  03-Mar-21  424.6445  18-May-20         57.16         80.35
# 31  ...  03-Mar-21   32.6030  18-May-20         31.43         46.99
# 30  ...  03-Mar-21   34.4720  18-May-20         31.53         46.90
# 65  ...  03-Mar-21   14.1904  18-May-20         25.60             -
#
#    3Y_SIP_RTN(%) 5Y_SIP_RTN(%) 10Y_SIP_RTN(%)     Plan Category
# 0          92.16        109.87              -   Direct     ELSS
# 1          86.86        102.63         218.21  Regular     ELSS
# 31         53.67         69.82              -  Regular     ELSS
# 30         49.89             -              -   Direct     ELSS
# 65             -             -              -  Regular     ELSS
#
# [5 rows x 86 columns]

# %%
#Replacing "-" with 'None' in the columns
elss_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
         '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)', '2018_RTN(%)',
         '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)", "2012_RTN(%)", "2011_RTN(%)",
         "2010_RTN(%)", '% Equity Holding', '% Debt Holding', '% MF Holding', '% Cash Holding', '% Other Holding',
         '1D Change(%)', '1Y_SIP_RTN(%)', '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)',
         "Apr'21", "Mar'21", "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20",
         "Jul'20", "Jun'20", "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19",
         "Q2'19", "Q1'19", "Q4'18", "Q3'18", "YTD", "MTD", "Turnover ratio(%)"
         ]] = elss_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
                       '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)',
                       '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)",
                       "2012_RTN(%)", "2011_RTN(%)", "2010_RTN(%)", '% Equity Holding', '% Debt Holding',
                       '% MF Holding', '% Cash Holding', '% Other Holding', '1D Change(%)', '1Y_SIP_RTN(%)',
                       '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)', "Apr'21", "Mar'21",
                       "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20", "Jul'20", "Jun'20",
                       "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19", "Q2'19", "Q1'19",
                       "Q4'18", "Q3'18", "YTD",'MTD', "Turnover ratio(%)"]].replace({'-' : None})

# %%
#Replacing "" with '0' in the columns

elss_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
         '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)', '2018_RTN(%)',
         '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)", "2012_RTN(%)", "2011_RTN(%)",
         "2010_RTN(%)", '% Equity Holding','% Debt Holding', '% MF Holding', '% Cash Holding', '% Other Holding',
         '1D Change(%)', '1Y_SIP_RTN(%)', '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)',
         '10Y_SIP_RTN(%)', "Apr'21", "Mar'21", "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20",
         "Sep'20", "Aug'20", "Jul'20", "Jun'20", "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20",
         "Q4'19", "Q3'19", "Q2'19", "Q1'19", "Q4'18", "Q3'18", "YTD", "MTD", "Turnover ratio(%)",
         "Standard Deviation", "Beta", "Sharpe Ratio", "Jension's Alpha", "Treynor's Ratio", 'Crisil Rank'
         ]] = elss_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
                       '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)',\
                       '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)",
                       "2012_RTN(%)", "2011_RTN(%)", "2010_RTN(%)", '% Equity Holding', '% Debt Holding',
                       '% MF Holding', '% Cash Holding', '% Other Holding', '1D Change(%)', '1Y_SIP_RTN(%)',
                       '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)', "Apr'21", "Mar'21",
                       "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20", "Jul'20", "Jun'20",
                       "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19", "Q2'19", "Q1'19",
                       "Q4'18", "Q3'18", "YTD",'MTD', "Turnover ratio(%)", "Standard Deviation", "Beta",
                       "Sharpe Ratio", "Jension's Alpha", "Treynor's Ratio", 'Crisil Rank']].fillna(value='0')

# %%
#Changing the datatype of the return & risk ratio columns

elss_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
         '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)', '2018_RTN(%)',
         '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)", "2012_RTN(%)", "2011_RTN(%)",
         "2010_RTN(%)", '% Equity Holding','% Debt Holding', '% MF Holding', '% Cash Holding', '% Other Holding',
         '1D Change(%)', '1Y_SIP_RTN(%)', '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)',
         '10Y_SIP_RTN(%)', "Apr'21", "Mar'21", "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20",
         "Sep'20", "Aug'20", "Jul'20", "Jun'20", "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20",
         "Q4'19", "Q3'19", "Q2'19", "Q1'19", "Q4'18", "Q3'18", "YTD", "MTD", "Turnover ratio(%)",
         "Standard Deviation", "Beta", "Sharpe Ratio", "Jension's Alpha", "Treynor's Ratio"
         ]] = elss_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
                       '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)',
                       '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)",
                       "2012_RTN(%)", "2011_RTN(%)", "2010_RTN(%)", '% Equity Holding', '% Debt Holding',
                       '% MF Holding', '% Cash Holding', '% Other Holding', '1D Change(%)', '1Y_SIP_RTN(%)',
                       '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)', "Apr'21", "Mar'21",
                       "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20", "Jul'20", "Jun'20",
                       "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19", "Q2'19", "Q1'19",
                       "Q4'18", "Q3'18", "YTD",'MTD', "Turnover ratio(%)", "Standard Deviation", "Beta",
                       "Sharpe Ratio", "Jension's Alpha", "Treynor's Ratio"]].apply(pd.to_numeric)

# %%
#Changing the datatype of the 'Crisil Rank' columns
elss_mf['Crisil Rank'] = elss_mf['Crisil Rank'].astype('int')

# %%
#Removing white spaces at both ends in all over the dataframe:

elss_mf.columns = elss_mf.columns.str.strip()

#Checking the data type of all columns in the DataFrame
elss_mf_dtype = elss_mf.dtypes

df_dtypes = pd.DataFrame(elss_mf_dtype)

# %%
#Using pandas dataframe.round()function to round off all the decimal values to 2 decimal places
elss_mf = elss_mf.round(2)

# %%
# #Exporting the consolidated elss mf data as a  csv file
# print("Shape of the dataframe:", elss_mf.shape)
#elss_mf.to_csv('final_elss_mf_data('+ str(pd.to_datetime('today').strftime('%d-%b-%Y %H:%M:%S')) + '.csv)',
#                 index=False)

# #Exporting the elss mf data columns with its datatype as a  csv file
# df_dtypes.to_csv('elss_mf_col_data_types('+ str(pd.to_datetime('today').strftime('%d-%b-%Y %H:%M:%S')) + '.csv)')

# %%
#Exctracting regular mutual funds
regular_mf = elss_mf.loc[elss_mf['Plan'] == 'Regular']
regular_mf.head()
# Out:
#                                        Scheme Name  Crisil Rank  AuM (Cr)  \
# 1                                   Quant Tax Plan            5    106.05
# 31       Mirae Asset Tax Saver Fund - Regular Plan            5   6934.49
# 65   Canara Robeco Equity Tax Saver - Regular Plan            5   2044.06
# 108      BOI AXA Tax Advantage Fund - Regular Plan            5    417.39
# 91                     Union Long Term Equity Fund            4    335.59
#
#      1W_RTN(%)  1M_RTN(%)  3M_RTN(%)  6M_RTN(%)  YTD_RTN(%)  1Y_RTN(%)  \
# 1         6.00       9.87      23.50      53.42       31.24     126.70
# 31        1.92       1.46       3.84      27.38       12.70      76.36
# 65        1.22       0.82       0.42      24.71       10.16      64.73
# 108       0.64       2.71       8.19      27.18       13.05      69.21
# 91        0.96       0.00       1.24      22.62        7.60      61.27
#
#      2Y_RTN(%)  ...  52WH as on  52W Low  52WL as on  1Y_SIP_RTN(%)  \
# 1        41.01  ...   03-Mar-21   424.64   18-May-20          57.16
# 31       22.74  ...   03-Mar-21    32.60   18-May-20          31.43
# 65       22.47  ...   03-Mar-21    14.19   18-May-20          25.60
# 108      29.51  ...   15-Feb-21     6.77   18-May-20          20.41
# 91       18.37  ...   07-May-21     5.56   19-May-20          23.15
#
#      2Y_SIP_RTN(%)  3Y_SIP_RTN(%)  5Y_SIP_RTN(%)  10Y_SIP_RTN(%)     Plan  \
# 1            80.35          86.86         102.63          218.21  Regular
# 31           46.99          53.67          69.82            0.00  Regular
# 65            0.00           0.00           0.00            0.00  Regular
# 108          28.35          34.33          45.47            0.00  Regular
# 91           31.65          35.41          43.55            0.00  Regular
#
#      Category
# 1        ELSS
# 31       ELSS
# 65       ELSS
# 108      ELSS
# 91       ELSS
#
# [5 rows x 86 columns]

# %%
# Basic statistics of regular mutual fund df
regular_mf.describe()
# Out:
#        Crisil Rank      AuM (Cr)  1W_RTN(%)  1M_RTN(%)  3M_RTN(%)  6M_RTN(%)  \
# count    65.000000     65.000000  65.000000  65.000000  65.000000  65.000000
# mean      1.723077   1972.964154   1.493538   1.513231   4.163846  27.706462
# std       1.736625   4405.958195   1.103339   2.220913   5.434483   9.041373
# min       0.000000     12.610000  -0.230000  -1.820000  -2.400000  12.560000
# 25%       0.000000     62.270000   0.890000   0.030000   0.420000  21.910000
# 50%       2.000000    289.850000   1.240000   0.970000   2.380000  25.370000
# 75%       3.000000   1836.790000   1.850000   2.160000   7.390000  31.060000
# max       5.000000  27870.000000   6.000000   9.870000  23.500000  53.420000
#
#        YTD_RTN(%)   1Y_RTN(%)  2Y_RTN(%)  3Y_RTN(%)  ...  % Other Holding  \
# count   65.000000   65.000000  65.000000  65.000000  ...        65.000000
# mean    11.335538   68.686000  16.553846   8.058462  ...         0.027077
# std      5.873693   16.619267   7.407031   5.828225  ...         0.202567
# min      2.020000   40.710000   0.000000  -1.000000  ...         0.000000
# 25%      7.890000   58.600000  12.720000   4.650000  ...         0.000000
# 50%      9.640000   64.800000  14.800000   7.650000  ...         0.000000
# 75%     14.490000   76.360000  18.860000  11.040000  ...         0.000000
# max     31.240000  126.700000  41.010000  25.650000  ...         1.630000
#
#               NAV  1D Change(%)    52W High     52W Low  1Y_SIP_RTN(%)  \
# count   65.000000     65.000000   65.000000   65.000000      65.000000
# mean    77.847538      0.247231   79.544308   44.776000      27.762769
# std    146.999840      0.360345  150.614196   83.919819       8.509979
# min     10.570000     -0.990000   10.750000    5.020000      13.880000
# 25%     13.840000      0.060000   14.240000    8.190000      22.130000
# 50%     24.210000      0.260000   24.780000   14.130000      25.600000
# 75%     67.960000      0.410000   67.960000   39.330000      30.970000
# max    768.570000      1.410000  787.420000  424.640000      57.160000
#
#        2Y_SIP_RTN(%)  3Y_SIP_RTN(%)  5Y_SIP_RTN(%)  10Y_SIP_RTN(%
#
#     Turnover ratio(%)  Standard Deviation  Beta
# 38               11.0               23.63  1.02
# 19                0.0               19.72  0.92
# 93              104.0                0.00  0.00

# %%
# Extracting last five years annual return for funds which have 5Y Return', '10Y Return' greater than 15%
mf_rtn_com = regular_mf.loc[(regular_mf['5Y_RTN(%)'] > 15) & (regular_mf['10Y_RTN(%)'] > 15)]
print("No. of funds having '5Y Return' & '10Y Return' greater than 15% is:", len(mf_rtn_com.index), 'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', 'NAV', '2020_RTN(%)', '2019_RTN(%)',
            '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)']]
# Out:
# No. of funds having '5Y Return' & '10Y Return' greater than 15% is: 3 Funds
#                                       Scheme Name  Crisil Rank  AuM (Cr)  \
# 38  IDFC Tax Advantage (ELSS) Fund - Regular Plan            4   2988.35
# 19              DSP Tax Saver Fund - Regular Plan            4   8056.26
# 93                     Axis Long Term Equity Fund            3  27870.00
#
#       NAV  2020_RTN(%)  2019_RTN(%)  2018_RTN(%)  2017_RTN(%)  2016_RTN(%)
# 38  65.26        32.40        15.15        -8.60        38.15         0.00
# 19  78.88        15.98         6.81        -7.66        27.84         1.27
# 93  13.39        11.85        -0.68       -14.43        26.47         0.00

# %% [markdown]
# ## Portfolio Turnover Ratio(PTR)
#
# Portfolio Turnover Ratio is the frequency in which the assets held under a fund has changed over the years. In simpler words, PTR provides a measurement on how many times the fund managers bought or sold the assets under a fund over a period of time. PTR is often determined by the market conditions and fund management style.
#
# Suppose an equity fund purchased stocks worth Rs. 375 crore and sold stocks worth Rs. 450 crore. The average AUM of the fund is Rs.1500 crore. In this case, the Portfolio turnover ratio of the fund is 25%, which means one-fourth of the stocks were traded.
#
# Funds that have higher turnover ratios, for example, can trigger higher costs for investors. First, a fund that’s actively managed may charge a higher expense ratio to cover the fund manager’s services. The expense ratio represents the percentage you pay to own the fund on an annualized basis. At the low end, you can find index funds with expense ratios around 0.50% to 0.10%. But the most expensive funds can easily have expense ratios over 1%.
#
# Turnover ratio can also give you an idea of what the fund’s investment strategy is, which is important for choosing funds that align with your goals and objectives. A growth mutual fund, for instance, may have a higher turnover ratio if the fund manager is constantly looking for the best growth stocks to drive returns. But a fund that uses a value investing approach may have a lower turnover ratio if the fund manager is buying assets that have the potential to appreciate over time.

# %%
# Top 10 low turnover ratio regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Turnover ratio(%)'] > 0)]
print("Top 10 low turnover ratio regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Turnover ratio(%)']].nsmallest(10, 'Turnover ratio(%)')
# Out:
# Top 10 low turnover ratio regular mutual funds are :
#                                            Scheme Name  Crisil Rank  AuM (Cr)  \
# 123  SBI Long Term Advantage Fund - Series I - Regu...            0     34.42
# 38       IDFC Tax Advantage (ELSS) Fund - Regular Plan            4   2988.35
# 62                                 HDFC Tax Saver Fund            1   7920.48
# 61                           ITI Long Term Equity Fund            0     75.51
# 9    Sundaram Long Term Micro Cap Tax Advantage Fun...            0     73.18
# 111  ICICI Prudential Long Term Wealth Enhancement ...            0     48.06
# 75   SBI Long Term Advantage Fund - Series V - Regu...            0    393.50
# 13   Sundaram Long Term Tax Advantage Fund - Series...            0     51.73
# 79       Edelweiss Long Term Equity Fund (Tax Savings)            3    164.60
# 85          Tata India Tax Savings Fund - Regular Plan            2   2637.17
#
#      1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Turnover ratio(%)
# 123      86.24      12.14      15.21        0.00   17.26               6.03
# 38       89.66       9.74      16.27       15.09   65.26              11.00
# 62       54.65       4.59      10.87        9.93   19.87              11.17
# 61       64.22       0.00       0.00        0.00   35.17              11.17
# 9        95.52      -1.00       0.00        0.00  260.04              12.00
# 111      64.85       6.80       0.00        0.00   11.37              13.31
# 75       58.80       9.83       0.00        0.00   11.45              17.00
# 13       99.88       2.94       0.00        0.00  186.22              21.00
# 79       57.40       7.65      11.87       12.12   10.75              23.67
# 85       57.78       9.39      14.32        0.00   21.48              31.00

# %%
# Top 10 high turnover ratio regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Turnover ratio(%)'] > 0)]
print("Top 10 high turnover ratio regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Turnover ratio(%)']].nlargest(10, 'Turnover ratio(%)')
# Out:
# Top 10 high turnover ratio regular mutual funds are :
#                                            Scheme Name  Crisil Rank  AuM (Cr)  \
# 127  SBI Long Term Advantage Fund - Series III - Re...            0     54.36
# 1                                       Quant Tax Plan            5    106.05
# 98                              Kotak Tax Saver Scheme            4   1836.79
# 97                           Baroda ELSS - 96 - Plan A            3    186.68
# 53                           Principal Tax Saving Fund            3    503.43
# 54   SBI Tax Advantage Fund - Series II - Regular Plan            0     35.47
# 101                Motilal Oswal Long Term Equity Fund            1   2048.02
# 93                          Axis Long Term Equity Fund            3  27870.00
# 29                       Franklin India Taxshield Fund            3   4375.42
# 51                         Principal Personal Tax Save            3    289.85
#
#      1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Turnover ratio(%)
# 127      83.25      14.55      15.04        0.00   91.65             1019.0
# 1       126.70      25.65      23.24       14.90  768.57              530.0
# 98       63.83      13.19      15.61       12.72   17.24              266.0
# 97       64.47       6.96      11.36        0.00   18.86              266.0
# 53       63.56       6.88      14.71       13.87   26.06              130.0
# 54       84.97      22.48      23.56        0.00   13.11              130.0
# 101      59.42       7.25      14.97        0.00   11.01              124.0
# 93       55.07      12.65      15.89       17.63   13.39              104.0
# 29       72.04       8.43      11.44       13.19   95.89               98.0
# 51       64.43       6.97      11.57       10.28   32.13               97.0

# %% [markdown]
# ## Standard Deviation (SD)
#
# The standard deviation of a stock or a mutual fund represents the riskiness of the stock or the mutual fund.
#
# Standard Deviation is a percentage, expressed as an annualised figure.
#
# Higher the standard Deviation, higher is the volatility of the asset. Higher the volatility, higher is the risk.
#
# Do note, volatility or Standard Deviation should not worry you. Markets are volatile, and equities are volatile, mutual funds are volatile; this is the very nature of markets. So if you can’t fathom watching your investment see-saw between gains and loss, then perhaps you should reconsider your investment decision inequities.

# %%
# Top 10 low standard deviation regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Standard Deviation'] > 0)]
print("Top 10 low standard deviation regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Standard Deviation']].nsmallest(10, 'Standard Deviation')
# Out:
# Top 10 low standard deviation regular mutual funds are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 25                        Nippon India Tax Saver Fund            1  11219.23
# 13  Sundaram Long Term Tax Advantage Fund - Series...            0     51.73
# 17  SBI Long Term Advantage Fund - Series IV - Reg...            0    156.65
# 28                   PGIM India Long Term Equity Fund            3    352.90
# 33           SBI Long Term Equity Fund - Regular Plan            3   9257.60
# 34  Sundaram Long Term Tax Advantage Fund - Series...            0     17.30
# 29                      Franklin India Taxshield Fund            3   4375.42
# 15         Parag Parikh Tax Saver Fund - Regular Plan            0    179.45
# 7   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     35.61
# 1                                      Quant Tax Plan            5    106.05
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Standard Deviation
# 25      68.79       2.30       8.25       11.72   67.96               18.08
# 13      99.88       2.94       0.00        0.00  186.22               18.31
# 17      88.63      17.57       0.00        0.00   86.34               18.37
# 28      66.49      10.72      14.55        0.00   57.73               18.45
# 33      62.59       9.47      11.82       12.15  122.09               18.63
# 34      66.80       9.52      14.14        0.00   20.77               18.73
# 29      72.04       8.43      11.44       13.19   95.89               19.02
# 15      70.49       0.00       0.00        0.00   98.11               19.09
# 7       99.54      -0.69       0.00        0.00  591.42               19.25
# 1      126.70      25.65      23.24       14.90  768.57               19.62

# %%
# Top 10 high standard deviation regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Standard Deviation'] > 0)]
print("Top 10 high standard deviation regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Standard Deviation']].nlargest(10, 'Standard Deviation')
# Out:
# Top 10 high standard deviation regular mutual funds are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 38      IDFC Tax Advantage (ELSS) Fund - Regular Plan            4   2988.35
# 20                            Quantum Tax Saving Fund            4     89.11
# 39                                   Taurus Taxshield            3     74.85
# 24  SBI Long Term Advantage Fund - Series VI - Reg...            0    306.41
# 5   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     38.37
# 47                         IDBI Equity Advantage Fund            1    506.42
# 46             UTI Long Term Equity Fund (Tax Saving)            4   1800.13
# 9   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     73.18
# 53                          Principal Tax Saving Fund            3    503.43
# 11  Sundaram Long Term Tax Advantage Fund - Series IV            0     34.90
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Standard Deviation
# 38      89.66       9.74      16.27       15.09   65.26               23.63
# 20      67.92       8.31       0.00        0.00  128.81               23.15
# 39      50.59       7.92      14.22       10.95   46.49               22.28
# 24      69.62       0.00       0.00        0.00   67.15               21.08
# 5      104.56      -0.82       0.00        0.00  181.23               21.03
# 47      43.82       5.37      10.45        0.00   18.13               20.94
# 46      65.16      11.06      13.98       11.84   25.37               20.92
# 9       95.52      -1.00       0.00        0.00  260.04               20.73
# 53      63.56       6.88      14.71       13.87   26.06               20.53
# 11      88.78       0.00       0.00        0.00  248.92               20.48

# %% [markdown]
# ## Beta Ratios
#
# A Beta Ratio in Mutual Funds offers investors the data on the degree of the volatility a Mutual Fund displays in response to market fluctuations. An investor can determine which fund would be best suited to meet his/her financial objectives.
#
# Suppose, the beta ratio of a specific Mutual Fund is 0.7 or 70%; it means the fund is 0.3 or 30% less volatile than the benchmark index. A Beta ratio value of 1 indicates a lower risk and lower growth potential compared to ratios at par or above 1.
#
# Investors with a low-risk appetite would always prefer a lower beta ratio in Mutual Funds as it indicates a steadier response to a volatile market condition. Similarly, investors with the investment objective of higher returns would prefer beta ratios of 1 or more than 1.

# %%
# Top 10 low beta regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Beta'] > 0)]
print("Top 10 low beta regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Beta']].nsmallest(10, 'Beta')
# Out:
# Top 10 low beta regular mutual funds are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 25                        Nippon India Tax Saver Fund            1  11219.23
# 13  Sundaram Long Term Tax Advantage Fund - Series...            0     51.73
# 17  SBI Long Term Advantage Fund - Series IV - Reg...            0    156.65
# 33           SBI Long Term Equity Fund - Regular Plan            3   9257.60
# 49  Sundaram Long Term Tax Advantage Fund - Series...            0     12.61
# 34  Sundaram Long Term Tax Advantage Fund - Series...            0     17.30
# 46             UTI Long Term Equity Fund (Tax Saving)            4   1800.13
# 47                         IDBI Equity Advantage Fund            1    506.42
# 15         Parag Parikh Tax Saver Fund - Regular Plan            0    179.45
# 28                   PGIM India Long Term Equity Fund            3    352.90
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Beta
# 25      68.79       2.30       8.25       11.72   67.96  0.77
# 13      99.88       2.94       0.00        0.00  186.22  0.79
# 17      88.63      17.57       0.00        0.00   86.34  0.79
# 33      62.59       9.47      11.82       12.15  122.09  0.80
# 49      64.80       9.77      14.14        0.00   23.28  0.80
# 34      66.80       9.52      14.14        0.00   20.77  0.80
# 46      65.16      11.06      13.98       11.84   25.37  0.83
# 47      43.82       5.37      10.45        0.00   18.13  0.83
# 15      70.49       0.00       0.00        0.00   98.11  0.83
# 28      66.49      10.72      14.55        0.00   57.73  0.85

# %%
# Top 10 high beta regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Beta'] > 0)]
print("Top 10 high beta regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Beta']].nlargest(10, 'Beta')
# Out:
# Top 10 high beta regular mutual funds are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 38      IDFC Tax Advantage (ELSS) Fund - Regular Plan            4   2988.35
# 20                            Quantum Tax Saving Fund            4     89.11
# 24  SBI Long Term Advantage Fund - Series VI - Reg...            0    306.41
# 39                                   Taurus Taxshield            3     74.85
# 5   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     38.37
# 9   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     73.18
# 31          Mirae Asset Tax Saver Fund - Regular Plan            5   6934.49
# 53                          Principal Tax Saving Fund            3    503.43
# 43  ICICI Prudential Long Term Equity Fund (Tax Sa...            3   8310.40
# 11  Sundaram Long Term Tax Advantage Fund - Series IV            0     34.90
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Beta
# 38      89.66       9.74      16.27       15.09   65.26  1.02
# 20      67.92       8.31       0.00        0.00  128.81  1.00
# 24      69.62       0.00       0.00        0.00   67.15  0.97
# 39      50.59       7.92      14.22       10.95   46.49  0.96
# 5      104.56      -0.82       0.00        0.00  181.23  0.96
# 9       95.52      -1.00       0.00        0.00  260.04  0.96
# 31      76.36      16.08      21.29        0.00   51.43  0.94
# 53      63.56       6.88      14.71       13.87   26.06  0.94
# 43      63.98      10.87      13.10       13.33   38.03  0.94
# 11      88.78       0.00       0.00        0.00  248.92  0.93

# %%
# Funds with 'Beta' lesser than 1.00
mf_tr = regular_mf.loc[(regular_mf['Beta'] < 1.00) & (regular_mf['Beta'] != 0.00)]
print("Funds with 'Beta' lesser than 1.00 are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Beta']]
# Out:
# Funds with 'Beta' lesser than 1.00 are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 1                                      Quant Tax Plan            5    106.05
# 31          Mirae Asset Tax Saver Fund - Regular Plan            5   6934.49
# 46             UTI Long Term Equity Fund (Tax Saving)            4   1800.13
# 19                  DSP Tax Saver Fund - Regular Plan            4   8056.26
# 39                                   Taurus Taxshield            3     74.85
# 33           SBI Long Term Equity Fund - Regular Plan            3   9257.60
# 53                          Principal Tax Saving Fund            3    503.43
# 51                        Principal Personal Tax Save            3    289.85
# 28                   PGIM India Long Term Equity Fund            3    352.90
# 43  ICICI Prudential Long Term Equity Fund (Tax Sa...            3   8310.40
# 29                      Franklin India Taxshield Fund            3   4375.42
# 25                        Nippon India Tax Saver Fund            1  11219.23
# 47                         IDBI Equity Advantage Fund            1    506.42
# 41           UTI Long Term Advantage Fund - Series IV            0    113.98
# 11  Sundaram Long Term Tax Advantage Fund - Series IV            0     34.90
# 13  Sundaram Long Term Tax Advantage Fund - Series...            0     51.73
# 49  Sundaram Long Term Tax Advantage Fund - Series...            0     12.61
# 34  Sundaram Long Term Tax Advantage Fund - Series...            0     17.30
# 5   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     38.37
# 3   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     37.10
# 7   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     35.61
# 9   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     73.18
# 24  SBI Long Term Advantage Fund - Series VI - Reg...            0    306.41
# 17  SBI Long Term Advantage Fund - Series IV - Reg...            0    156.65
# 15         Parag Parikh Tax Saver Fund - Regular Plan            0    179.45
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Beta
# 1      126.70      25.65      23.24       14.90  768.57  0.87
# 31      76.36      16.08      21.29        0.00   51.43  0.94
# 46      65.16      11.06      13.98       11.84   25.37  0.83
# 19      69.89      13.37      16.42       15.06   78.88  0.92
# 39      50.59       7.92      14.22       10.95   46.49  0.96
# 33      62.59       9.47      11.82       12.15  122.09  0.80
# 53      63.56       6.88      14.71       13.87   26.06  0.94
# 51      64.43       6.97      11.57       10.28   32.13  0.86
# 28      66.49      10.72      14.55        0.00   57.73  0.85
# 43      63.98      10.87      13.10       13.33   38.03  0.94
# 29      72.04       8.43      11.44       13.19   95.89  0.87
# 25      68.79       2.30       8.25       11.72   67.96  0.77
# 47      43.82       5.37      10.45        0.00   18.13  0.83
# 41      76.48       4.27       0.00        0.00   41.07  0.88
# 11      88.78       0.00       0.00        0.00  248.92  0.93
# 13      99.88       2.94       0.00        0.00  186.22  0.79
# 49      64.80       9.77      14.14        0.00   23.28  0.80
# 34      66.80       9.52      14.14        0.00   20.77  0.80
# 5      104.56      -0.82       0.00        0.00  181.23  0.96
# 3      103.83       0.38       0.00        0.00  713.45  0.92
# 7       99.54      -0.69       0.00        0.00  591.42  0.90
# 9       95.52      -1.00       0.00        0.00  260.04  0.96
# 24      69.62       0.00       0.00        0.00   67.15  0.97
# 17      88.63      17.57       0.00        0.00   86.34  0.79
# 15      70.49       0.00       0.00        0.00   98.11  0.83

# %%
# Funds with 'Beta' greater than 1.00
mf_tr = regular_mf.loc[(regular_mf['Beta'] > 1.00) & (regular_mf['Beta'] != 0.00)]
print("Funds with 'Beta' lesser than 1.00 are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Beta']]
# Out:
# Funds with 'Beta' lesser than 1.00 are :
#                                       Scheme Name  Crisil Rank  AuM (Cr)  \
# 38  IDFC Tax Advantage (ELSS) Fund - Regular Plan            4   2988.35
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)    NAV  Beta
# 38      89.66       9.74      16.27       15.09  65.26  1.02

# %% [markdown]
# ## What is Sharpe Ratio?
#
# Sharpe Ratio of a mutual fund reveals its potential risk-adjusted returns. The risk-adjusted returns are the returns earned by an investment over the returns generated by any risk-free asset such as a fixed deposit. However, higher returns indicate extra risk. Higher Sharpe Ratio means greater returns from an investment but with a higher risk level. Therefore, it justifies the underlying volatility of the funds. The investors aiming for higher returns will have to invest in funds with higher risk factors.
#
# Investments with less than 1.00 Sharpe Ratio do not generate high returns. Contrarily, investment with Sharpe Ratio of 1.00 to 3.00 or above have higher returns subsequently.

# %%
# Top 10 low sharpe ratio regular mutual funds are
#mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] > 0)]
print("Top 10 low 'Sharpe Ratio' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']].nsmallest(10, 'Sharpe Ratio')
# Out:
# Top 10 low 'Sharpe Ratio' regular mutual funds are :
#                                       Scheme Name  Crisil Rank  AuM (Cr)  \
# 38  IDFC Tax Advantage (ELSS) Fund - Regular Plan            4   2988.35
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)    NAV  Sharpe Ratio
# 38      89.66       9.74      16.27       15.09  65.26          0.11

# %%
# Top 10 high sharpe ratio regular mutual funds are
#mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] > 0)]
print("Top 10 high 'Sharpe Ratio' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']].nlargest(10, 'Sharpe Ratio')
# Out:
# Top 10 high 'Sharpe Ratio' regular mutual funds are :
#                                       Scheme Name  Crisil Rank  AuM (Cr)  \
# 38  IDFC Tax Advantage (ELSS) Fund - Regular Plan            4   2988.35
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)    NAV  Sharpe Ratio
# 38      89.66       9.74      16.27       15.09  65.26          0.11

# %%
# Funds with 'Sharpe Ratio' greater than or equal to 3.00
mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] >= 3.00)]
print("Top 10 high 'Sharpe Ratio' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']]
# Out:
# Top 10 high 'Sharpe Ratio' regular mutual funds are :
# Empty DataFrame
# Columns: [Scheme Name, Crisil Rank, AuM (Cr), 1Y_RTN(%), 3Y_RTN(%), 5Y_RTN(%), 10Y_RTN(%), NAV, Sharpe Ratio]
# Index: []

# %%
# Funds with 'Sharpe Ratio' greater than to 2.00 & lesser than 2.99
mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] > 2.00) & (regular_mf['Sharpe Ratio'] < 2.99)]
print("Top 10 high 'Sharpe Ratio' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']]
# Out:
# Top 10 high 'Sharpe Ratio' regular mutual funds are :
# Empty DataFrame
# Columns: [Scheme Name, Crisil Rank, AuM (Cr), 1Y_RTN(%), 3Y_RTN(%), 5Y_RTN(%), 10Y_RTN(%), NAV, Sharpe Ratio]
# Index: []

# %%
# Funds with 'Sharpe Ratio' greater than to 1.00 & lesser than 1.99
mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] > 1.00) & (regular_mf['Sharpe Ratio'] < 1.99)]
print("Top 10 high 'Sharpe Ratio' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']]
# Out:
# Top 10 high 'Sharpe Ratio' regular mutual funds are :
# Empty DataFrame
# Columns: [Scheme Name, Crisil Rank, AuM (Cr), 1Y_RTN(%), 3Y_RTN(%), 5Y_RTN(%), 10Y_RTN(%), NAV, Sharpe Ratio]
# Index: []

# %%
# Funds with 'Sharpe Ratio' lesser than 1.00
mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] != 0.00) & (regular_mf['Sharpe Ratio'] < 1.00)]
print("Funds with 'Sharpe Ratio' lesser than 1.00 are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']]
# Out:
# Funds with 'Sharpe Ratio' lesser than 1.00 are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 1                                      Quant Tax Plan            5    106.05
# 31          Mirae Asset Tax Saver Fund - Regular Plan            5   6934.49
# 46             UTI Long Term Equity Fund (Tax Saving)            4   1800.13
# 20                            Quantum Tax Saving Fund            4     89.11
# 38      IDFC Tax Advantage (ELSS) Fund - Regular Plan            4   2988.35
# 19                  DSP Tax Saver Fund - Regular Plan            4   8056.26
# 39                                   Taurus Taxshield            3     74.85
# 33           SBI Long Term Equity Fund - Regular Plan            3   9257.60
# 53                          Principal Tax Saving Fund            3    503.43
# 51                        Principal Personal Tax Save            3    289.85
# 28                   PGIM India Long Term Equity Fund            3    352.90
# 43  ICICI Prudential Long Term Equity Fund (Tax Sa...            3   8310.40
# 29                      Franklin India Taxshield Fund            3   4375.42
# 25                        Nippon India Tax Saver Fund            1  11219.23
# 47                         IDBI Equity Advantage Fund            1    506.42
# 41           UTI Long Term Advantage Fund - Series IV            0    113.98
# 11  Sundaram Long Term Tax Advantage Fund - Series IV            0     34.90
# 13  Sundaram Long Term Tax Advantage Fund - Series...            0     51.73
# 49  Sundaram Long Term Tax Advantage Fund - Series...            0     12.61
# 34  Sundaram Long Term Tax Advantage Fund - Series...            0     17.30
# 5   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     38.37
# 3   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     37.10
# 7   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     35.61
# 9   Sundaram Long Term Micro Cap Tax Advantage Fun...            0     73.18
# 24  SBI Long Term Advantage Fund - Series VI - Reg...            0    306.41
# 17  SBI Long Term Advantage Fund - Series IV - Reg...            0    156.65
# 15         Parag Parikh Tax Saver Fund - Regular Plan            0    179.45
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Sharpe Ratio
# 1      126.70      25.65      23.24       14.90  768.57          0.29
# 31      76.36      16.08      21.29        0.00   51.43          0.26
# 46      65.16      11.06      13.98       11.84   25.37         -0.18
# 20      67.92       8.31       0.00        0.00  128.81          0.01
# 38      89.66       9.74      16.27       15.09   65.26          0.11
# 19      69.89      13.37      16.42       15.06   78.88          0.60
# 39      50.59       7.92      14.22       10.95   46.49          0.17
# 33      62.59       9.47      11.82       12.15  122.09          0.98
# 53      63.56       6.88      14.71       13.87   26.06          0.32
# 51      64.43       6.97      11.57       10.28   32.13          0.25
# 28      66.49      10.72      14.55        0.00   57.73          0.11
# 43      63.98      10.87      13.10       13.33   38.03          0.13
# 29      72.04       8.43      11.44       13.19   95.89          0.19
f_tr = regular_mf.loc[(regular_mf['5Y_RTN(%)'] > 0)]
print("Top 10 high 'AuM (Cr)' regular mutual funds are :")
mf_tr =  mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)',
       'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']].nlargest(10, 'AuM (Cr)')
mf_tr
# Out:
# Top 10 high 'AuM (Cr)' regular mutual funds are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 25                        Nippon India Tax Saver Fund            1  11219.23
# 33           SBI Long Term Equity Fund - Regular Plan            3   9257.60
# 43  ICICI Prudential Long Term Equity Fund (Tax Sa...            3   8310.40
# 19                  DSP Tax Saver Fund - Regular Plan            4   8056.26
# 31          Mirae Asset Tax Saver Fund - Regular Plan            5   6934.49
# 29                      Franklin India Taxshield Fund            3   4375.42
# 38      IDFC Tax Advantage (ELSS) Fund - Regular Plan            4   2988.35
# 46             UTI Long Term Equity Fund (Tax Saving)            4   1800.13
# 47                         IDBI Equity Advantage Fund            1    506.42
# 53                          Principal Tax Saving Fund            3    503.43
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)  Sharpe Ratio  \
# 25      68.79       2.30       8.25       11.72          0.11
# 33      62.59       9.47      11.82       12.15          0.98
# 43      63.98      10.87      13.10       13.33          0.13
# 19      69.89      13.37      16.42       15.06          0.60
# 31      76.36      16.08      21.29        0.00          0.26
# 29      72.04       8.43      11.44       13.19          0.19
# 38      89.66       9.74      16.27       15.09          0.11
# 46      65.16      11.06      13.98       11.84         -0.18
# 47      43.82       5.37      10.45        0.00         -0.13
# 53      63.56       6.88      14.71       13.87          0.32
#
#     Turnover ratio(%)  Standard Deviation  Beta
# 25               81.0               18.08  0.77
# 33                0.0               18.63  0.80
# 43                0.0               20.39  0.94
# 19                0.0               19.72  0.92
# 31               35.0               19.87  0.94
# 29               98.0               19.02  0.87
# 38               11.0               23.63  1.02
# 46               47.0               20.92  0.83
# 47               44.0               20.94  0.83
# 53              130.0               20.53  0.94

# %%
# Top 10 low AuM (Cr) regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['5Y_RTN(%)'] > 0)]
print("Top 10 low 'AuM (Cr)' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)',
       'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']].nsmallest(10, 'AuM (Cr)')
# Out:
# Top 10 low 'AuM (Cr)' regular mutual funds are :
#                                            Scheme Name  Crisil Rank  AuM (Cr)  \
# 49   Sundaram Long Term Tax Advantage Fund - Series...            0     12.61
# 34   Sundaram Long Term Tax Advantage Fund - Series...            0     17.30
# 73   SBI Tax Advantage Fund - Series III - Regular ...            0     25.52
# 125  SBI Long Term Advantage Fund - Series II - Reg...            0     29.02
# 123  SBI Long Term Advantage Fund - Series I - Regu...            0     34.42
# 54   SBI Tax Advantage Fund - Series II - Regular Plan            0     35.47
# 105                                   JM Tax Gain Fund            4     52.53
# 127  SBI Long Term Advantage Fund - Series III - Re...            0     54.36
# 89                       Navi Long Term Advantage Fund            2     62.27
# 39                                    Taurus Taxshield            3     74.85
#
#      1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)  Sharpe Ratio  \
# 49       64.80       9.77      14.14        0.00          0.01
# 34       66.80       9.52      14.14        0.00          0.26
# 73       83.16      24.15      23.58        0.00          0.00
# 125      83.36      13.45      16.45        0.00          0.00
# 123      86.24      12.14      15.21        0.00          0.00
# 54       84.97      22.48      23.56        0.00          0.00
# 105      71.77      11.73      16.50       13.37          0.00
# 127      83.25      14.55      15.04        0.00          0.00
# 89       54.31       7.43      11.23        0.00          0.00
# 39       50.59       7.92      14.22       10.95          0.17
#
#      Turnover ratio(%)  Standard Deviation  Beta
# 49               42.00               20.07  0.80
# 34                0.00               18.73  0.80
# 73               54.00                0.00  0.00
# 125              39.00                0.00  0.00
# 123               6.03                0.00  0.00
# 54              130.00                0.00  0.00
# 105              40.00                0.00  0.00
# 127            1019.00                0.00  0.00
# 89                0.00                0.00  0.00
# 39                0.00               22.28  0.96

# %%
# Extracting funds returns 10% in 3year & 5year period which have AuM in between 0Crs to 500Crs
mf_rtn_com = regular_mf.loc[(regular_mf['AuM (Cr)'] > 0) & (regular_mf['AuM (Cr)'] < 500) &
                            (regular_mf['3Y_RTN(%)'] > 10) & (regular_mf['5Y_RTN(%)'] > 10)]
print("No. of funds eturns 10% in 3year & 5year period which have AuM in between 0Crs to 500Crs is:",
      len(mf_rtn_com.index),
      'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds eturns 10% in 3year & 5year period which have AuM in between 0Crs to 500Crs is: 11 Funds
#                                            Scheme Name  Crisil Rank  AuM (Cr)  \
# 1                                       Quant Tax Plan            5    106.05
# 108          BOI AXA Tax Advantage Fund - Regular Plan            5    417.39
# 91                         Union Long Term Equity Fund            4    335.59
# 105                                   JM Tax Gain Fund            4     52.53
# 28                    PGIM India Long Term Equity Fund            3    352.90
# 69                   BNP Paribas Long Term Equity Fund            3    495.33
# 73   SBI Tax Advantage Fund - Series III - Regular ...            0     25.52
# 54   SBI Tax Advantage Fund - Series II - Regular Plan            0     35.47
# 127  SBI Long Term Advantage Fund - Series III - Re...            0     54.36
# 125  SBI Long Term Advantage Fund - Series II - Reg...            0     29.02
# 123  SBI Long Term Advantage Fund - Series I - Regu...            0     34.42
#
#      1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Sharpe Ratio  \
# 1       126.70      25.65      23.24       14.90  768.57          0.29
# 108      69.21      12.22      18.33       14.22   10.97          0.00
# 91       61.27      11.47      12.45        0.00   11.52          0.00
# 105      71.77      11.73      16.50       13.37   49.02          0.00
# 28       66.49      10.72      14.55        0.00   57.73          0.11
# 69       52.50      11.04      12.40       14.13   13.84          0.00
# 73       83.16      24.15      23.58        0.00   45.35          0.00
# 54       84.97      22.48      23.56        0.00   13.11          0.00
# 127      83.25      14.55      15.04        0.00   91.65          0.00
# 125      83.36      13.45      16.45        0.00   14.17          0.00
# 123      86.24      12.14      15.21        0.00   17.26          0.00
#
#      Turnover ratio(%)  Standard Deviation  Beta
# 1               530.00               19.62  0.87
# 108               0.00                0.00  0.00
# 91               43.24                0.00  0.00
# 105              40.00                0.00  0.00
# 28               42.00               18.45  0.85
# 69                0.00                0.00  0.00
# 73               54.00                0.00  0.00
# 54              130.00                0.00  0.00
# 127            1019.00                0.00  0.00
# 125              39.00                0.00  0.00
# 123               6.03                0.00  0.00

# %%
# Extracting funds returns 10% in 3year & 5year period which have AuM in between 500Crs to 1000Crs
mf_rtn_com = regular_mf.loc[(regular_mf['AuM (Cr)'] > 500) & (regular_mf['AuM (Cr)'] < 1000) &
                            (regular_mf['3Y_RTN(%)'] > 10) & (regular_mf['5Y_RTN(%)'] > 10)]
print("No. of funds having '3Y Return', '5Y Return' & '10Y Return' greater than 10% is:", len(mf_rtn_com.index),
      'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds having '3Y Return', '5Y Return' & '10Y Return' greater than 10% is: 0 Funds
# Empty DataFrame
# Columns: [Scheme Name, Crisil Rank, AuM (Cr), 1Y_RTN(%), 3Y_RTN(%), 5Y_RTN(%), 10Y_RTN(%), NAV, Sharpe Ratio, Turnover ratio(%), Standard Deviation, Beta]
# Index: []

# %%
# Extracting funds returns 10% in 3year & 5year period which have AuM in between 1000Crs to 1500Crs
mf_rtn_com = regular_mf.loc[(regular_mf['AuM (Cr)'] > 1000) & (regular_mf['AuM (Cr)'] < 1500) &
                            (regular_mf['3Y_RTN(%)'] > 10) & (regular_mf['5Y_RTN(%)'] > 10)]
print("No. of funds returns 10% in 3year & 5year period which have AuM in between 1000Crs to 1500Crs is:",
      len(mf_rtn_com.index),
      'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds returns 10% in 3year & 5year period which have AuM in between 1000Crs to 1500Crs is: 0 Funds
# Empty DataFrame
# Columns: [Scheme Name, Crisil Rank, AuM (Cr), 1Y_RTN(%), 3Y_RTN(%), 5Y_RTN(%), 10Y_RTN(%), NAV, Sharpe Ratio, Turnover ratio(%), Standard Deviation, Beta]
# Index: []

# %%
# Extracting funds returns 10% in 3year & 5year period which have AuM in between 1500 to 20000Crs
mf_rtn_com = regular_mf.loc[(regular_mf['AuM (Cr)'] > 1500) & (regular_mf['AuM (Cr)'] < 20000) &
                            (regular_mf['3Y_RTN(%)'] > 10) & (regular_mf['5Y_RTN(%)'] > 10)]
print("No. of funds returns 10% in 3year & 5year period which have AuM in between 1500Crs to 20000Crs is:",
      len(mf_rtn_com.index),
      'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds returns 10% in 3year & 5year period which have AuM in between 1500Crs to 1500Crs is: 7 Funds
#                                            Scheme Name  Crisil Rank  AuM (Cr)  \
# 31           Mirae Asset Tax Saver Fund - Regular Plan            5   6934.49
# 65       Canara Robeco Equity Tax Saver - Regular Plan            5   2044.06
# 46              UTI Long Term Equity Fund (Tax Saving)            4   1800.13
# 98                              Kotak Tax Saver Scheme            4   1836.79
# 19                   DSP Tax Saver Fund - Regular Plan            4   8056.26
# 121                             Invesco India Tax Plan            3   1512.41
# 43   ICICI Prudential Long Term Equity Fund (Tax Sa...            3   8310.40
#
#      1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)    NAV  Sharpe Ratio  \
# 31       76.36      16.08      21.29        0.00  51.43          0.26
# 65       64.73      16.50      17.18       14.11  25.44          0.00
# 46       65.16      11.06      13.98       11.84  25.37         -0.18
# 98       63.83      13.19      15.61       12.72  17.24          0.00
# 19       69.89      13.37      16.42       15.06  78.88          0.60
# 121      56.46      10.54      14.85       14.64  66.53          0.00
# 43       63.98      10.87      13.10       13.33  38.03          0.13
#
#      Turnover ratio(%)  Standard Deviation  Beta
# 31                35.0               19.87  0.94
# 65                78.0                0.00  0.00
# 46                47.0               20.92  0.83
# 98               266.0                0.00  0.00
# 19                 0.0               19.72  0.92
# 121                0.0                0.00  0.00
# 43                 0.0               20.39  0.94
