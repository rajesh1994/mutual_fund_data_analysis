# %%
# Importing respective modules
import pandas as pd
import re

# %%
# Reading elss mutual funds csv file
lc_mf = pd.read_csv('lc_mf_data(11-May-2021 13:32:01).csv')

# %%
# Extracting a plan from "Scheme Name" column
scheme_name = list(lc_mf['Scheme Name'])
plan = []
for i in scheme_name:
    #print(type(i))
    plan.append(re.findall("Direct|Regular", str(i)))
#plan
for p in plan:
    if len(p) == 0:
        #print(type(p))
        p.append("Regular")
lc_mf['Plan'] = plan

# %%
# Extracting a category from "Scheme Name" column
scheme_name = list(lc_mf['Scheme Name'])
category = []
for i in scheme_name:
    #print(type(i))
    category.append(re.findall("Large Cap Fund", str(i)))
lc_mf['Category'] = category

# %%
# Modifiying 'Scheme Name' column
lc_mf['Scheme Name'] = lc_mf['Scheme Name'].str.replace(' - GrowthLarge Cap Fund', '')

# %%
#Replacing "']" & "['" string with "" in Plan columns
lc_mf['Plan'] = lc_mf['Plan'].astype(str).str.replace("\['","", regex=True)
lc_mf['Plan'] = lc_mf['Plan'].astype(str).str.replace("']","", regex=True)

#Replacing "']" & "['" string with "" in Category columns
lc_mf['Category'] = lc_mf['Category'].astype(str).str.replace("\['","", regex=True)
lc_mf['Category'] = lc_mf['Category'].astype(str).str.replace("']","", regex=True)

# %%
#Replacing "ELSS', 'ELSS" string with "ELSS" in Category columns
lc_mf['Category'] = lc_mf['Category'].astype(str).str.replace("Large Cap Fund', 'Large Cap Fund","Large Cap Fund", regex=True)

#Replacing "%" string with "" in Crisil Rank, % Debt Holding, No of instruments in portfolio,
# % MF Holding, % Other Holding, Turnover ratio, MTD, 10Y_SIP_RTN(%) & 5Y_SIP_RTN(%) columns
lc_mf[['% Debt Holding', 'No of instruments in portfolio',
          '% MF Holding', '% Other Holding', 'Turnover ratio(%)',
          'MTD', '10Y_SIP_RTN(%)', '5Y_SIP_RTN(%)'         
         ]] = lc_mf[['% Debt Holding', 'No of instruments in portfolio',
                        '% MF Holding', '% Other Holding', 'Turnover ratio(%)',
                        'MTD', '10Y_SIP_RTN(%)', '5Y_SIP_RTN(%)'
                        ]].replace("%", "", regex=True)

#Replacing "-" string with "0" in Crisil Rank columns
lc_mf['Crisil Rank'] = lc_mf['Crisil Rank'].replace("-", "", regex=True)

# %%
#Replacing "-" string with "0" in Crisil Rank columns
lc_mf['Crisil Rank'] = lc_mf['Crisil Rank'].replace("", "0", regex=True)

#Replacing "%" with '' in the column
lc_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
         '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)', '2018_RTN(%)',
         '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)", "2012_RTN(%)", "2011_RTN(%)",
         "2010_RTN(%)", '% Equity Holding', '% Debt Holding', '% MF Holding', '% Cash Holding', '% Other Holding',
         '1D Change(%)', '1Y_SIP_RTN(%)', '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)',
         "Apr'21", "Mar'21", "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20",
         "Jul'20", "Jun'20", "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19",
         "Q2'19", "Q1'19", "Q4'18", "Q3'18", "YTD", "MTD", "Turnover ratio(%)"
         ]] = lc_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
                       '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)',
                       '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)",
                       "2012_RTN(%)", "2011_RTN(%)", "2010_RTN(%)", '% Equity Holding', '% Debt Holding',
                       '% MF Holding', '% Cash Holding', '% Other Holding', '1D Change(%)', '1Y_SIP_RTN(%)',
                       '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)', "Apr'21", "Mar'21",
                       "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20", "Jul'20", "Jun'20",
                       "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19", "Q2'19", "Q1'19",
                       "Q4'18", "Q3'18", "YTD",'MTD', "Turnover ratio(%)"
                       ]].replace("%", "", regex=True)
print("Shape of the dataframe:", lc_mf.shape)
lc_mf.head()
# Out:
# Shape of the dataframe: (66, 86)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0                    HDFC Top 100 Fund - Direct Plan           1  18445.21
# 1                                  HDFC Top 100 Fund           1  18445.21
# 2            PGIM India Large Cap Fund - Direct Plan           3    308.64
# 3                          PGIM India Large Cap Fund           3    308.64
# 4  Mahindra Manulife Large Cap Pragati Yojana - D...           0    108.26
#
#   1W_RTN(%) 1M_RTN(%) 3M_RTN(%) 6M_RTN(%) YTD_RTN(%) 1Y_RTN(%) 2Y_RTN(%)  ...  \
# 0      3.41      2.44     -0.74     25.03      11.57     63.04     11.13  ...
# 1      3.40      2.40     -0.87     24.69      11.36     62.11     10.51  ...
# 2      3.39      2.52      2.01     20.87       9.22     58.26     17.91  ...
# 3      3.36      2.39      1.63     19.96       8.63     55.89     16.28  ...
# 4      3.11      3.21      2.42     26.11      13.62     61.97     19.51  ...
#
#   52WH as on   52W Low 52WL as on 1Y_SIP_RTN(%) 2Y_SIP_RTN(%) 3Y_SIP_RTN(%)  \
# 0  03-Mar-21  364.9760  18-May-20         31.63         37.09         38.16
# 1  03-Mar-21  347.8820  18-May-20         31.07         36.02         36.54
# 2  03-Mar-21  368.2100  18-May-20         28.02         34.07             -
# 3  03-Mar-21  346.3501  18-May-20         26.79         27.44         27.88
# 4  10-May-21  146.7900  18-May-20         26.71         31.46             -
#
#   5Y_SIP_RTN(%) 10Y_SIP_RTN(%)     Plan        Category
# 0         45.37              -   Direct  Large Cap Fund
# 1         42.38          93.07  Regular  Large Cap Fund
# 2             -              -   Direct  Large Cap Fund
# 3         38.92              -  Regular  Large Cap Fund
# 4             -              -   Direct  Large Cap Fund
#
# [5 rows x 86 columns]

# %%
#Sorting a lc_mf dataframe by "Crisil Rank Column"
lc_mf.sort_values(by=['Crisil Rank', 'Scheme Name', 'AuM (Cr)'], inplace=True, ascending=False)
print("Shape of the dataframe:", lc_mf.shape)
lc_mf.head()
# Out:
# Shape of the dataframe: (66, 86)
#                                           Scheme Name Crisil Rank  AuM (Cr)  \
# 41          UTI Mastershare Unit Scheme - Direct Plan           5   7734.48
# 43                        UTI Mastershare Unit Scheme           5   7734.48
# 64                  Kotak Bluechip Fund - Direct Plan           5   2411.04
# 65                                Kotak Bluechip Fund           5   2411.04
# 39  Canara Robeco Bluechip Equity Fund - Regular Plan           5   2476.82
#
#    1W_RTN(%) 1M_RTN(%) 3M_RTN(%) 6M_RTN(%) YTD_RTN(%) 1Y_RTN(%) 2Y_RTN(%)  \
# 41      1.78      0.66     -0.04     20.79       7.95     61.80     18.80
# 43      1.76      0.58     -0.26     20.25       7.60     60.32     17.77
# 64      1.37     -0.10     -0.36     19.58       8.07     62.47     19.61
# 65      1.35     -0.20     -0.65     18.87       7.60     60.58     18.27
# 39      1.85      0.62     -1.22     18.73       7.00     55.13     21.96
#
#     ... 52WH as on 52W Low 52WL as on 1Y_SIP_RTN(%) 2Y_SIP_RTN(%)  \
# 41  ...  15-Feb-21   22.15  18-May-20         19.54         25.80
# 43  ...  15-Feb-21   26.04  18-May-20         19.54         22.87
# 64  ...  03-Mar-21   10.00  24-Dec-20           NaN           NaN
# 65  ...  15-Feb-21    9.86  30-Oct-20           NaN           NaN
# 39  ...  03-Mar-21   19.94  18-May-20         20.57         23.30
#
#    3Y_SIP_RTN(%) 5Y_SIP_RTN(%) 10Y_SIP_RTN(%)     Plan        Category
# 41         29.91         41.70              -   Direct  Large Cap Fund
# 43         24.16         29.12              -  Regular  Large Cap Fund
# 64           NaN           NaN            NaN   Direct  Large Cap Fund
# 65           NaN           NaN            NaN  Regular  Large Cap Fund
# 39         25.60         32.49          76.38  Regular  Large Cap Fund
#
# [5 rows x 86 columns]

# %%
#Replacing "-" with 'None' in the columns
lc_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
         '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)', '2018_RTN(%)',
         '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)", "2012_RTN(%)", "2011_RTN(%)",
         "2010_RTN(%)", '% Equity Holding', '% Debt Holding', '% MF Holding', '% Cash Holding', '% Other Holding',
         '1D Change(%)', '1Y_SIP_RTN(%)', '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)',
         "Apr'21", "Mar'21", "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20",
         "Jul'20", "Jun'20", "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19",
         "Q2'19", "Q1'19", "Q4'18", "Q3'18", "YTD", "MTD", "Turnover ratio(%)"
         ]] = lc_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
                       '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)',
                       '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)",
                       "2012_RTN(%)", "2011_RTN(%)", "2010_RTN(%)", '% Equity Holding', '% Debt Holding',
                       '% MF Holding', '% Cash Holding', '% Other Holding', '1D Change(%)', '1Y_SIP_RTN(%)',
                       '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)', "Apr'21", "Mar'21",
                       "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20", "Jul'20", "Jun'20",
                       "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19", "Q2'19", "Q1'19",
                       "Q4'18", "Q3'18", "YTD",'MTD', "Turnover ratio(%)"]].replace({'-' : None})

# %%
#Replacing "" with '0' in the columns

lc_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
         '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)', '2018_RTN(%)',
         '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)", "2012_RTN(%)", "2011_RTN(%)",
         "2010_RTN(%)", '% Equity Holding','% Debt Holding', '% MF Holding', '% Cash Holding', '% Other Holding',
         '1D Change(%)', '1Y_SIP_RTN(%)', '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)',
         '10Y_SIP_RTN(%)', "Apr'21", "Mar'21", "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20",
         "Sep'20", "Aug'20", "Jul'20", "Jun'20", "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20",
         "Q4'19", "Q3'19", "Q2'19", "Q1'19", "Q4'18", "Q3'18", "YTD", "MTD", "Turnover ratio(%)",
         "Standard Deviation", "Beta", "Sharpe Ratio", "Jension's Alpha", "Treynor's Ratio", 'Crisil Rank'
         ]] = lc_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
                       '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)',\
                       '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)",
                       "2012_RTN(%)", "2011_RTN(%)", "2010_RTN(%)", '% Equity Holding', '% Debt Holding',
                       '% MF Holding', '% Cash Holding', '% Other Holding', '1D Change(%)', '1Y_SIP_RTN(%)',
                       '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)', "Apr'21", "Mar'21",
                       "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20", "Jul'20", "Jun'20",
                       "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19", "Q2'19", "Q1'19",
                       "Q4'18", "Q3'18", "YTD",'MTD', "Turnover ratio(%)", "Standard Deviation", "Beta",
                       "Sharpe Ratio", "Jension's Alpha", "Treynor's Ratio", 'Crisil Rank']].fillna(value='0')

# %%
#Changing the datatype of the return & risk ratio columns

lc_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
         '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)', '2018_RTN(%)',
         '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)", "2012_RTN(%)", "2011_RTN(%)",
         "2010_RTN(%)", '% Equity Holding','% Debt Holding', '% MF Holding', '% Cash Holding', '% Other Holding',
         '1D Change(%)', '1Y_SIP_RTN(%)', '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)',
         '10Y_SIP_RTN(%)', "Apr'21", "Mar'21", "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20",
         "Sep'20", "Aug'20", "Jul'20", "Jun'20", "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20",
         "Q4'19", "Q3'19", "Q2'19", "Q1'19", "Q4'18", "Q3'18", "YTD", "MTD", "Turnover ratio(%)",
         "Standard Deviation", "Beta", "Sharpe Ratio", "Jension's Alpha", "Treynor's Ratio"
         ]] = lc_mf[['1W_RTN(%)', '1M_RTN(%)', '3M_RTN(%)', '6M_RTN(%)', 'YTD_RTN(%)', '1Y_RTN(%)',
                       '2Y_RTN(%)', '3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', '2020_RTN(%)', '2019_RTN(%)',
                       '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)', '2015_RTN(%)', '2014_RTN(%)', "2013_RTN(%)",
                       "2012_RTN(%)", "2011_RTN(%)", "2010_RTN(%)", '% Equity Holding', '% Debt Holding',
                       '% MF Holding', '% Cash Holding', '% Other Holding', '1D Change(%)', '1Y_SIP_RTN(%)',
                       '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)', "Apr'21", "Mar'21",
                       "Feb'21", "Jan'21", "Dec'20", "Nov'20", "Oct'20", "Sep'20", "Aug'20", "Jul'20", "Jun'20",
                       "QTD", "Q1'21", "Q4'20", "Q3'20", "Q2'20", "Q1'20", "Q4'19", "Q3'19", "Q2'19", "Q1'19",
                       "Q4'18", "Q3'18", "YTD",'MTD', "Turnover ratio(%)", "Standard Deviation", "Beta",
                       "Sharpe Ratio", "Jension's Alpha", "Treynor's Ratio"]].apply(pd.to_numeric)

# %%
#Changing the datatype of the 'Crisil Rank' columns
lc_mf['Crisil Rank'] = lc_mf['Crisil Rank'].astype('int')

# %%
#Removing white spaces at both ends in all over the dataframe:

lc_mf.columns = lc_mf.columns.str.strip()

#Checking the data type of all columns in the DataFrame
lc_mf_dtype = lc_mf.dtypes

df_dtypes = pd.DataFrame(lc_mf_dtype)

# %%
#Using pandas dataframe.round()function to round off all the decimal values to 2 decimal places
lc_mf = lc_mf.round(2)

# %%
# #Exporting the consolidated elss mf data as a  csv file
# print("Shape of the dataframe:", lc_mf.shape)
#lc_mf.to_csv('final_lc_mf_data('+ str(pd.to_datetime('today').strftime('%d-%b-%Y %H:%M:%S')) + '.csv)',
#                 index=False)

# #Exporting the elss mf data columns with its datatype as a  csv file
# df_dtypes.to_csv('lc_mf_col_data_types('+ str(pd.to_datetime('today').strftime('%d-%b-%Y %H:%M:%S')) + '.csv)')

# %%
#Exctracting regular mutual funds
regular_mf = lc_mf.loc[lc_mf['Plan'] == 'Regular']
regular_mf.head()
# Out:
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 43                        UTI Mastershare Unit Scheme            5   7734.48
# 65                                Kotak Bluechip Fund            5   2411.04
# 39  Canara Robeco Bluechip Equity Fund - Regular Plan            5   2476.82
# 31                  SBI Blue Chip Fund - Regular Plan            4  26464.26
# 56                                  JM Large Cap Fund            4     54.20
#
#     1W_RTN(%)  1M_RTN(%)  3M_RTN(%)  6M_RTN(%)  YTD_RTN(%)  1Y_RTN(%)  \
# 43       1.76       0.58      -0.26      20.25        7.60      60.32
# 65       1.35      -0.20      -0.65      18.87        7.60      60.58
# 39       1.85       0.62      -1.22      18.73        7.00      55.13
# 31       2.08       0.25      -1.91      22.01        8.05      63.25
# 56       1.53       0.71      -0.83      11.62        4.32      37.15
#
#     2Y_RTN(%)  ...  52WH as on  52W Low  52WL as on  1Y_SIP_RTN(%)  \
# 43      17.77  ...   15-Feb-21    26.04   18-May-20          19.54
# 65      18.27  ...   15-Feb-21     9.86   30-Oct-20           0.00
# 39      21.96  ...   03-Mar-21    19.94   18-May-20          20.57
# 31      17.02  ...   15-Feb-21    39.60   18-May-20          21.52
# 56      12.97  ...   10-May-21     8.09   18-May-20          14.75
#
#     2Y_SIP_RTN(%)  3Y_SIP_RTN(%)  5Y_SIP_RTN(%)  10Y_SIP_RTN(%)
# %%
# Extracting funds which have '3Y Return' & '5Y Return' greater than 12%
mf_rtn_com = regular_mf.loc[(regular_mf['3Y_RTN(%)'] > 12) & (regular_mf['5Y_RTN(%)'] > 12)]
print("No. of funds having '3Y Return' & '5Y Return' greater than 12% is:", len(mf_rtn_com.index), 'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds having '3Y Return' & '5Y Return' greater than 12% is: 5 Funds
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 65                                Kotak Bluechip Fund            5   2411.04
# 39  Canara Robeco Bluechip Equity Fund - Regular Plan            5   2476.82
# 48               Mirae Asset Large Cap Fund - Regular            3  23993.39
# 53                         BNP Paribas Large Cap Fund            3   1029.84
# 44                                 Axis Bluechip Fund            3  24598.26
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)    NAV  Sharpe Ratio  \
# 65      60.58      12.35      13.35       12.07  12.43           0.0
# 39      55.13      15.81      16.34       13.23  32.53           0.0
# 48      59.25      12.06      15.74       15.02  34.38           0.0
# 53      49.69      12.43      12.67       13.53  14.16           0.0
# 44      47.31      14.85      15.80       13.93  34.97           0.0
#
#     Turnover ratio(%)  Standard Deviation  Beta
# 65                0.0                 0.0   0.0
# 39                0.0                 0.0   0.0
# 48                0.0                 0.0   0.0
# 53               57.0                 0.0   0.0
# 44                0.0                 0.0   0.0

# %%
# Extracting last five years annual return for funds which have 3Y Return', '5Y Return' greater than 12%
mf_rtn_com = regular_mf.loc[(regular_mf['3Y_RTN(%)'] > 12) & (regular_mf['5Y_RTN(%)'] > 12)]
print("Last five years annual return for funds which have '5Y Return' & '10Y Return'greater than 10% is:",
      len(mf_rtn_com.index), '\nFunds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', 'NAV', '2020_RTN(%)', '2019_RTN(%)',
            '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)']]
# Out:
# Last five years annual return for funds which have '5Y Return' & '10Y Return'greater than 10% is: 5
# Funds
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 65                                Kotak Bluechip Fund            5   2411.04
# 39  Canara Robeco Bluechip Equity Fund - Regular Plan            5   2476.82
# 48               Mirae Asset Large Cap Fund - Regular            3  23993.39
# 53                         BNP Paribas Large Cap Fund            3   1029.84
# 44                                 Axis Bluechip Fund            3  24598.26
#
#       NAV  2020_RTN(%)  2019_RTN(%)  2018_RTN(%)  2017_RTN(%)  2016_RTN(%)
# 65  12.43         0.09         0.00         0.00         0.00         0.00
# 39  32.53        13.24        15.03        -2.89        28.16         2.35
# 48  34.38        24.38        17.35         5.26        32.77         2.41
# 53  14.16        18.36        10.85         0.34        29.57         3.23
# 44  34.97         8.39        15.90        -1.21        27.37         4.89

# %%
# Extracting funds which have '3Y Return' & '5Y Return' greater than 15%
mf_rtn_com = regular_mf.loc[(regular_mf['3Y_RTN(%)'] > 15) & (regular_mf['5Y_RTN(%)'] > 15)]
print("No. of funds having '3Y Return' & '5Y Return' greater than 15% is:", len(mf_rtn_com.index), 'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
            'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds having '3Y Return' & '5Y Return' greater than 15% is: 1 Funds
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 39  Canara Robeco Bluechip Equity Fund - Regular Plan            5   2476.82
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)    NAV  Sharpe Ratio  \
# 39      55.13      15.81      16.34       13.23  32.53           0.0
#
#     Turnover ratio(%)  Standard Deviation  Beta
# 39                0.0                 0.0   0.0

# %%
# Extracting last five years annual return for funds which have 3Y Return', '5Y Return' greater than 15%
mf_rtn_com = regular_mf.loc[(regular_mf['3Y_RTN(%)'] > 15) & (regular_mf['5Y_RTN(%)'] > 15)]
print("No. of funds having '3Y Return' & '5Y Return' greater than 15% is:", len(mf_rtn_com.index), 'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', 'NAV', '2020_RTN(%)', '2019_RTN(%)',
            '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)']]
# Out:
# No. of funds having '3Y Return' & '5Y Return' greater than 15% is: 1 Funds
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 39  Canara Robeco Bluechip Equity Fund - Regular Plan            5   2476.82
#
#       NAV  2020_RTN(%)  2019_RTN(%)  2018_RTN(%)  2017_RTN(%)  2016_RTN(%)
# 39  32.53        13.24        15.03        -2.89        28.16         2.35

# %%
# Extracting funds which have '5Y Return' & '10Y Return' greater than 15%
mf_rtn_com = regular_mf.loc[(regular_mf['5Y_RTN(%)'] > 15) & (regular_mf['10Y_RTN(%)'] > 15)]
print("No. of funds having '5Y Return' & '10Y Return' greater than 15% is:", len(mf_rtn_com.index), 'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
            'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds having '5Y Return' & '10Y Return' greater than 15% is: 1 Funds
#                              Scheme Name  Crisil Rank  AuM (Cr)  1Y_RTN(%)  \
# 48  Mirae Asset Large Cap Fund - Regular            3  23993.39      59.25
#
#     3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)    NAV  Sharpe Ratio  Turnover ratio(%)  \
# 48      12.06      15.74       15.02  34.38           0.0                0.0
#
#     Standard Deviation  Beta
# 48                 0.0   0.0

# %%
# Extracting last five years annual return for funds which have 5Y Return', '10Y Return' greater than 15%
mf_rtn_com = regular_mf.loc[(regular_mf['5Y_RTN(%)'] > 15) & (regular_mf['10Y_RTN(%)'] > 15)]
print("No. of funds having '5Y Return' & '10Y Return' greater than 15% is:", len(mf_rtn_com.index), 'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', 'NAV', '2020_RTN(%)', '2019_RTN(%)',
            '2018_RTN(%)', '2017_RTN(%)', '2016_RTN(%)']]
# Out:
# No. of funds having '5Y Return' & '10Y Return' greater than 15% is: 1 Funds
#                              Scheme Name  Crisil Rank  AuM (Cr)    NAV  \
# 48  Mirae Asset Large Cap Fund - Regular            3  23993.39  34.38
#
#     2020_RTN(%)  2019_RTN(%)  2018_RTN(%)  2017_RTN(%)  2016_RTN(%)
# 48        24.38        17.35         5.26        32.77         2.41

# %% [markdown]
# ## Portfolio Turnover Ratio(PTR)
#
# Portfolio Turnover Ratio is the frequency in which the assets held under a fund has changed over the years. In simpler words, PTR provides a measurement on how many times the fund managers bought or sold the assets under a fund over a period of time. PTR is often determined by the market conditions and fund management style.
#
# Suppose an equity fund purchased stocks worth Rs. 375 crore and sold stocks worth Rs. 450 crore. The average AUM of the fund is Rs.1500 crore. In this case, the Portfolio turnover ratio of the fund is 25%, which means one-fourth of the stocks were traded.
#
# Funds that have higher turnover ratios, for example, can trigger higher costs for investors. First, a fund that’s actively managed may charge a higher expense ratio to cover the fund manager’s services. The expense ratio represents the percentage you pay to own the fund on an annualized basis. At the low end, you can find index funds with expense ratios around 0.50% to 0.10%. But the most expensive funds can easily have expense ratios over 1%.
#
# Turnover ratio can also give you an idea of what the fund’s investment strategy is, which is important for choosing funds that align with your goals and objectives. A growth mutual fund, for instance, may have a higher turnover ratio if the fund manager is constantly looking for the best growth stocks to drive returns. But a fund that uses a value investing approach may have a lower turnover ratio if the fund manager is buying assets that have the potential to appreciate over time.

# %%
# Top 10 low turnover ratio regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Turnover ratio(%)'] > 0)]
print("Top 10 low turnover ratio regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Turnover ratio(%)']].nsmallest(10, 'Turnover ratio(%)')
# Out:
# Top 10 low turnover ratio regular mutual funds are :
#                        Scheme Name  Crisil Rank  AuM (Cr)  1Y_RTN(%)  \
# 53      BNP Paribas Large Cap Fund            3   1029.84      49.69
# 50      Navi Large Cap Equity Fund            3     95.55      56.01
# 51      HSBC Large Cap Equity Fund            3    689.71      53.65
# 25  IDBI India Top 100 Equity Fund            4    425.99      55.49
# 12     Taurus Largecap Equity Fund            2     29.13      49.89
# 1                HDFC Top 100 Fund            1  18445.21      62.11
#
#     3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Turnover ratio(%)
# 53      12.43      12.67       13.53   14.16              57.00
# 50       9.33      12.01        0.00   20.18              66.00
# 51       9.92      13.37       10.29   19.02              66.00
# 25      11.33      11.91        0.00   91.85              67.68
# 12       7.98       9.54        8.05  289.75              84.00
# 1        9.70      13.23       10.90  589.93             199.00

# %%
# Top 10 high turnover ratio regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Turnover ratio(%)'] > 0)]
print("Top 10 high turnover ratio regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Turnover ratio(%)']].nlargest(10, 'Turnover ratio(%)')
# Out:
# Top 10 high turnover ratio regular mutual funds are :
#                        Scheme Name  Crisil Rank  AuM (Cr)  1Y_RTN(%)  \
# 1                HDFC Top 100 Fund            1  18445.21      62.11
# 12     Taurus Largecap Equity Fund            2     29.13      49.89
# 25  IDBI India Top 100 Equity Fund            4    425.99      55.49
# 50      Navi Large Cap Equity Fund            3     95.55      56.01
# 51      HSBC Large Cap Equity Fund            3    689.71      53.65
# 53      BNP Paribas Large Cap Fund            3   1029.84      49.69
#
#     3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Turnover ratio(%)
# 1        9.70      13.23       10.90  589.93             199.00
# 12       7.98       9.54        8.05  289.75              84.00
# 25      11.33      11.91        0.00   91.85              67.68
# 50       9.33      12.01        0.00   20.18              66.00
# 51       9.92      13.37       10.29   19.02              66.00
# 53      12.43      12.67       13.53   14.16              57.00

# %% [markdown]
# ## Standard Deviation (SD)
#
# The standard deviation of a stock or a mutual fund represents the riskiness of the stock or the mutual fund.
#
# Standard Deviation is a percentage, expressed as an annualised figure.
#
# Higher the standard Deviation, higher is the volatility of the asset. Higher the volatility, higher is the risk.
#
# Do note, volatility or Standard Deviation should not worry you. Markets are volatile, and equities are volatile, mutual funds are volatile; this is the very nature of markets. So if you can’t fathom watching your investment see-saw between gains and loss, then perhaps you should reconsider your investment decision inequities.

# %%
# Top 10 low standard deviation regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Standard Deviation'] > 0)]
print("Top 10 low standard deviation regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Standard Deviation']].nsmallest(10, 'Standard Deviation')
# Out:
# Top 10 low standard deviation regular mutual funds are :
#                           Scheme Name  Crisil Rank  AuM (Cr)  1Y_RTN(%)  \
# 3           PGIM India Large Cap Fund            3    308.64      55.89
# 15        Nippon India Large Cap Fund            2   9828.19      65.07
# 23                Union Largecap Fund            3    181.90      56.16
# 11  ITI Large Cap Fund - Regular Plan            0    163.77       0.00
# 6        Franklin India Bluechip Fund            4   5910.59      71.85
# 1                   HDFC Top 100 Fund            1  18445.21      62.11
# 19     ICICI Prudential Bluechip Fund            3  26082.64      60.93
# 12        Taurus Largecap Equity Fund            2     29.13      49.89
# 17     Baroda Large Cap Fund - Plan A            4     40.90      54.39
# 10  ITI Large Cap Fund - Regular Plan            0      0.00       0.00
#
#     3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Standard Deviation
# 3       10.91      12.50       11.45  619.92               18.34
# 15       8.57      13.26       12.39  257.65               19.40
# 23       9.33       0.00        0.00   59.08               19.76
# 11       0.00       0.00        0.00  281.26               20.05
# 6       11.26      12.00       11.26  220.12               20.46
# 1        9.70      13.23       10.90  589.93               20.48
# 19      11.03      14.23       13.03   90.57               20.58
# 12       7.98       9.54        8.05  289.75               20.70
# 17      11.46      12.87        7.64  164.49               20.96
# 10       0.00       0.00        0.00  316.33               21.01

# %%
# Top 10 high standard deviation regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Standard Deviation'] > 0)]
print("Top 10 high standard deviation regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Standard Deviation']].nlargest(10, 'Standard Deviation')
# Out:
# Top 10 high standard deviation regular mutual funds are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 7   Mahindra Manulife Large Cap Pragati Yojana - R...            0    108.26
# 25                     IDBI India Top 100 Equity Fund            4    425.99
# 21  Aditya Birla Sun Life Frontline Equity Fund - ...            2  19292.47
# 10                  ITI Large Cap Fund - Regular Plan            0      0.00
# 17                     Baroda Large Cap Fund - Plan A            4     40.90
# 12                        Taurus Largecap Equity Fund            2     29.13
# 19                     ICICI Prudential Bluechip Fund            3  26082.64
# 1                                   HDFC Top 100 Fund            1  18445.21
# 6                        Franklin India Bluechip Fund            4   5910.59
# 11                  ITI Large Cap Fund - Regular Plan            0    163.77
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Standard Deviation
# 7       59.15       0.00       0.00        0.00  287.31               22.71
# 25      55.49      11.33      11.91        0.00   91.85               21.96
# 21      61.24       9.61      12.48       12.72  119.75               21.12
# 10       0.00       0.00       0.00        0.00  316.33               21.01
# 17      54.39      11.46      12.87        7.64  164.49               20.96
# 12      49.89       7.98       9.54        8.05  289.75               20.70
# 19      60.93      11.03      14.23       13.03   90.57               20.58
# 1       62.11       9.70      13.23       10.90  589.93               20.48
# 6       71.85      11.26      12.00       11.26  220.12               20.46
# 11       0.00       0.00       0.00        0.00  281.26               20.05

# %% [markdown]
# ## Beta Ratios
#
# A Beta Ratio in Mutual Funds offers investors the data on the degree of the volatility a Mutual Fund displays in response to market fluctuations. An investor can determine which fund would be best suited to meet his/her financial objectives.
#
# Suppose, the beta ratio of a specific Mutual Fund is 0.7 or 70%; it means the fund is 0.3 or 30% less volatile than the benchmark index. A Beta ratio value of 1 indicates a lower risk and lower growth potential compared to ratios at par or above 1.
#
# Investors with a low-risk appetite would always prefer a lower beta ratio in Mutual Funds as it indicates a steadier response to a volatile market condition. Similarly, investors with the investment objective of higher returns would prefer beta ratios of 1 or more than 1.

# %%
# Top 10 low beta regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Beta'] > 0)]
print("Top 10
lesser than 1.00 are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Beta']]
# Out:
# Funds with 'Beta' lesser than 1.00 are :
#                                          Scheme Name  Crisil Rank  AuM (Cr)  \
# 7  Mahindra Manulife Large Cap Pragati Yojana - R...            0    108.26
#
#    1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Beta
# 7      59.15        0.0        0.0         0.0  287.31  1.01

# %% [markdown]
# ## What is Sharpe Ratio?
#
# Sharpe Ratio of a mutual fund reveals its potential risk-adjusted returns. The risk-adjusted returns are the returns earned by an investment over the returns generated by any risk-free asset such as a fixed deposit. However, higher returns indicate extra risk. Higher Sharpe Ratio means greater returns from an investment but with a higher risk level. Therefore, it justifies the underlying volatility of the funds. The investors aiming for higher returns will have to invest in funds with higher risk factors.
#
# Investments with less than 1.00 Sharpe Ratio do not generate high returns. Contrarily, investment with Sharpe Ratio of 1.00 to 3.00 or above have higher returns subsequently.

# %%
# Top 10 low sharpe ratio regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] > 0)]
print("Top 10 low 'Sharpe Ratio' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']].nsmallest(10, 'Sharpe Ratio')
# Out:
# Top 10 low 'Sharpe Ratio' regular mutual funds are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 23                                Union Largecap Fund            3    181.90
# 12                        Taurus Largecap Equity Fund            2     29.13
# 7   Mahindra Manulife Large Cap Pragati Yojana - R...            0    108.26
# 25                     IDBI India Top 100 Equity Fund            4    425.99
# 1                                   HDFC Top 100 Fund            1  18445.21
# 10                  ITI Large Cap Fund - Regular Plan            0      0.00
# 21  Aditya Birla Sun Life Frontline Equity Fund - ...            2  19292.47
# 6                        Franklin India Bluechip Fund            4   5910.59
# 19                     ICICI Prudential Bluechip Fund            3  26082.64
# 11                  ITI Large Cap Fund - Regular Plan            0    163.77
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Sharpe Ratio
# 23      56.16       9.33       0.00        0.00   59.08          0.22
# 12      49.89       7.98       9.54        8.05  289.75          0.22
# 7       59.15       0.00       0.00        0.00  287.31          0.28
# 25      55.49      11.33      11.91        0.00   91.85          0.31
# 1       62.11       9.70      13.23       10.90  589.93          0.33
# 10       0.00       0.00       0.00        0.00  316.33          0.35
# 21      61.24       9.61      12.48       12.72  119.75          0.36
# 6       71.85      11.26      12.00       11.26  220.12          0.38
# 19      60.93      11.03      14.23       13.03   90.57          0.39
# 11       0.00       0.00       0.00        0.00  281.26          0.40

# %%
# Top 10 high sharpe ratio regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] > 0)]
print("Top 10 high 'Sharpe Ratio' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']].nlargest(10, 'Sharpe Ratio')
# Out:
# Top 10 high 'Sharpe Ratio' regular mutual funds are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 3                           PGIM India Large Cap Fund            3    308.64
# 17                     Baroda Large Cap Fund - Plan A            4     40.90
# 15                        Nippon India Large Cap Fund            2   9828.19
# 11                  ITI Large Cap Fund - Regular Plan            0    163.77
# 19                     ICICI Prudential Bluechip Fund            3  26082.64
# 6                        Franklin India Bluechip Fund            4   5910.59
# 21  Aditya Birla Sun Life Frontline Equity Fund - ...            2  19292.47
# 10                  ITI Large Cap Fund - Regular Plan            0      0.00
# 1                                   HDFC Top 100 Fund            1  18445.21
# 25                     IDBI India Top 100 Equity Fund            4    425.99
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Sharpe Ratio
# 3       55.89      10.91      12.50       11.45  619.92          0.61
# 17      54.39      11.46      12.87        7.64  164.49          0.45
# 15      65.07       8.57      13.26       12.39  257.65          0.41
# 11       0.00       0.00       0.00        0.00  281.26          0.40
# 19      60.93      11.03      14.23       13.03   90.57          0.39
# 6       71.85      11.26      12.00       11.26  220.12          0.38
# 21      61.24       9.61      12.48       12.72  119.75          0.36
# 10       0.00       0.00       0.00        0.00  316.33          0.35
# 1       62.11       9.70      13.23       10.90  589.93          0.33
# 25      55.49      11.33      11.91        0.00   91.85          0.31

# %%
# Funds with 'Sharpe Ratio' greater than or equal to 3.00
mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] >= 3.00)]
print("Top 10 high 'Sharpe Ratio' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']]
# Out:
# Top 10 high 'Sharpe Ratio' regular mutual funds are :
# Empty DataFrame
# Columns: [Scheme Name, Crisil Rank, AuM (Cr), 1Y_RTN(%), 3Y_RTN(%), 5Y_RTN(%), 10Y_RTN(%), NAV, Sharpe Ratio]
# Index: []

# %%
# Funds with 'Sharpe Ratio' greater than to 2.00 & lesser than 2.99
mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] > 2.00) & (regular_mf['Sharpe Ratio'] < 2.99)]
print("Top 10 high 'Sharpe Ratio' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']]
# Out:
# Top 10 high 'Sharpe Ratio' regular mutual funds are :
# Empty DataFrame
# Columns: [Scheme Name, Crisil Rank, AuM (Cr), 1Y_RTN(%), 3Y_RTN(%), 5Y_RTN(%), 10Y_RTN(%), NAV, Sharpe Ratio]
# Index: []

# %%
# Funds with 'Sharpe Ratio' greater than to 1.00 & lesser than 1.99
mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] > 1.00) & (regular_mf['Sharpe Ratio'] < 1.99)]
print("Top 10 high 'Sharpe Ratio' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']]
# Out:
# Top 10 high 'Sharpe Ratio' regular mutual funds are :
# Empty DataFrame
# Columns: [Scheme Name, Crisil Rank, AuM (Cr), 1Y_RTN(%), 3Y_RTN(%), 5Y_RTN(%), 10Y_RTN(%), NAV, Sharpe Ratio]
# Index: []

# %%
# Funds with 'Sharpe Ratio' lesser than 1.00
mf_tr = regular_mf.loc[(regular_mf['Sharpe Ratio'] != 0.00) & (regular_mf['Sharpe Ratio'] < 1.00)]
print("Funds with 'Sharpe Ratio' lesser than 1.00 are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)',
            '5Y_RTN(%)', '10Y_RTN(%)', 'NAV', 'Sharpe Ratio']]
# Out:
# Funds with 'Sharpe Ratio' lesser than 1.00 are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 25                     IDBI India Top 100 Equity Fund            4    425.99
# 6                        Franklin India Bluechip Fund            4   5910.59
# 17                     Baroda Large Cap Fund - Plan A            4     40.90
# 23                                Union Largecap Fund            3    181.90
# 3                           PGIM India Large Cap Fund            3    308.64
# 19                     ICICI Prudential Bluechip Fund            3  26082.64
# 12                        Taurus Largecap Equity Fund            2     29.13
# 15                        Nippon India Large Cap Fund            2   9828.19
# 21  Aditya Birla Sun Life Frontline Equity Fund - ...            2  19292.47
# 1                                   HDFC Top 100 Fund            1  18445.21
# 7   Mahindra Manulife Large Cap Pragati Yojana - R...            0    108.26
# 11                  ITI Large Cap Fund - Regular Plan            0    163.77
# 10                  ITI Large Cap Fund - Regular Plan            0      0.00
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Sharpe Ratio
# 25      55.49      11.33      11.91        0.00   91.85          0.31
# 6       71.85      11.26      12.00       11.26  220.12          0.38
# 17      54.39      11.46      12.87        7.64  164.49          0.45
# 23      56.16       9.33       0.00        0.00   59.08          0.22
# 3       55.89      10.91      12.50       11.45  619.92          0.61
# 19      60.93      11.03      14.23       13.03   90.57          0.39
# 12      49.89       7.98       9.54        8.05  289.75          0.22
# 15      65.07       8.57      13.26       12.39  257.65          0.41
# 21      61.24       9.61      12.48       12.72  119.75          0.36
# 1       62.11       9.70      13.23       10.90  589.93          0.33
# 7       59.15       0.00       0.00        0.00  287.31          0.28
# 11       0.00       0.00       0.00        0.00  281.26          0.40
# 10       0.00       0.00       0.00        0.00  316.33          0.35

# %%
# Extracting funds which have 3Y Return', '5Y Return' & '10Y Return' greater than 25%
mf_rtn_com = regular_mf.loc[(regular_mf['3Y_SIP_RTN(%)'] > 25) & (regular_mf['5Y_SIP_RTN(%)'] > 25) &
                            (regular_mf['10Y_SIP_RTN(%)'] > 25)]
print("No. of funds having '3Y SIP Return', '5Y SIP Return' & '10Y SIP Return' greater than 25% is:",
      len(mf_rtn_com.index),
      'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '3Y_SIP_RTN(%)', '5Y_SIP_RTN(%)', '10Y_SIP_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds having '3Y SIP Return', '5Y SIP Return' & '10Y SIP Return' greater than 25% is: 13 Funds
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 39  Canara Robeco Bluechip Equity Fund - Regular Plan            5   2476.82
# 31                  SBI Blue Chip Fund - Regular Plan            4  26464.26
# 25                     IDBI India Top 100 Equity Fund            4    425.99
# 6                        Franklin India Bluechip Fund            4   5910.59
# 17                     Baroda Large Cap Fund - Plan A            4     40.90
# 50                         Navi Large Cap Equity Fund            3     95.55
# 48               Mirae Asset Large Cap Fund - Regular            3  23993.39
# 33                           L&T India Large Cap Fund            3    626.07
# 51                         HSBC Large Cap Equity Fund            3    689.71
# 53                         BNP Paribas Large Cap Fund            3   1029.84
# 21  Aditya Birla Sun Life Frontline Equity Fund - ...            2  19292.47
# 1                                   HDFC Top 100 Fund            1  18445.21
# 11                  ITI Large Cap Fund - Regular Plan            0    163.77
#
#     3Y_SIP_RTN(%)  5Y_SIP_RTN(%)  10Y_SIP_RTN(%)     NAV  Sharpe Ratio  \
# 39          25.60          32.49           76.38   32.53          0.00
# 31          30.79          38.83           80.00   66.29          0.00
# 25          33.88          44.21          103.51   91.85          0.31
# 6           26.19          35.53          100.37  220.12          0.38
# 17          29.91          37.51          101.28  164.49          0.45
# 50          32.39          52.32          123.35   20.18          0.00
# 48          31.54          42.73          107.84   34.38          0.00
# 33          30.73          44.53          131.81   46.80          0.00
# 51          27.63          37.73           86.94   19.02          0.00
# 53          28.03          38.37           83.17   14.16          0.00
# 21          31.31          40.28           95.98  119.75          0.36
# 1           36.54          42.38           93.07  589.93          0.33
# 11          33.12          41.54          114.78  281.26          0.40
#
#     Turnover ratio(%)  Standard Deviation  Beta
#
#
#     Turnover ratio(%)  Standard Deviation  Beta
# 39               0.00                0.00  0.00
# 31               0.00                0.00  0.00
# 56               0.00                0.00  0.00
# 25              67.68               21.96  0.97
# 6                0.00               20.46  0.92
# 17               0.00               20.96  0.97
# 23               0.00               19.76  0.91
# 3                0.00               18.34  0.81
# 50              66.00                0.00  0.00
# 48               0.00                0.00  0.00
# 33               0.00                0.00  0.00
# 36               0.00                0.00  0.00
# 19               0.00               20.58  0.93
# 51              66.00                0.00  0.00
# 53              57.00                0.00  0.00
# 12              84.00               20.70  0.93
# 28               0.00                0.00  0.00
# 15               0.00               19.40  0.85
# 21               0.00               21.12  0.96
# 1              199.00               20.48  0.92
# 29               0.00                0.00  0.00
# 47               0.00                0.00  0.00
# 7                0.00               22.71  1.01
# 11               0.00               20.05  0.93
# 10               0.00               21.01  0.98

# %%
# Extracting funds which have '1Y SIP Return', '2Y SIP Return' & '3Y SIP Return' greater than 25%
mf_rtn_com = regular_mf.loc[(regular_mf['1Y_SIP_RTN(%)'] > 25) & (regular_mf['2Y_SIP_RTN(%)'] > 25) &
                            (regular_mf['3Y_SIP_RTN(%)'] > 25)]
print("No. of funds having '1Y SIP Return', '2Y SIP Return' & '3Y SIP Return' greater than 25% is:",
      len(mf_rtn_com.index),
      'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_SIP_RTN(%)', '2Y_SIP_RTN(%)', '3Y_SIP_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']].nlargest(10, 'AuM (Cr)')
# Out:
# No. of funds having '1Y SIP Return', '2Y SIP Return' & '3Y SIP Return' greater than 25% is: 4 Funds
#                                          Scheme Name  Crisil Rank  AuM (Cr)  \
# 1                                  HDFC Top 100 Fund            1  18445.21
# 6                       Franklin India Bluechip Fund            4   5910.59
# 3                          PGIM India Large Cap Fund            3    308.64
# 7  Mahindra Manulife Large Cap Pragati Yojana - R...            0    108.26
#
#    1Y_SIP_RTN(%)  2Y_SIP_RTN(%)  3Y_SIP_RTN(%)     NAV  Sharpe Ratio  \
# 1          31.07          36.02          36.54  589.93          0.33
# 6          26.18          26.31          26.19  220.12          0.38
# 3          26.79          27.44          27.88  619.92          0.61
# 7          25.86          26.96          28.06  287.31          0.28
#
#    Turnover ratio(%)  Standard Deviation  Beta
# 1              199.0               20.48  0.92
# 6                0.0               20.46  0.92
# 3                0.0               18.34  0.81
# 7                0.0               22.71  1.01

# %%
# Top 10 high AuM (Cr) regular mutual funds are
#mf_tr = regular_mf.loc[(regular_mf['5Y_RTN(%)'] > 0)]
print("Top 10 high 'AuM (Cr)' regular mutual funds are :")
mf_tr =  mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)',
       'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']].nlargest(10, 'AuM (Cr)')
mf_tr
# Out:
# Top 10 high 'AuM (Cr)' regular mutual funds are :
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 19                     ICICI Prudential Bluechip Fund            3  26082.64
# 21  Aditya Birla Sun Life Frontline Equity Fund - ...            2  19292.47
# 1                                   HDFC Top 100 Fund            1  18445.21
# 15                        Nippon India Large Cap Fund            2   9828.19
# 6                        Franklin India Bluechip Fund            4   5910.59
# 25                     IDBI India Top 100 Equity Fund            4    425.99
# 3                           PGIM India Large Cap Fund            3    308.64
# 23                                Union Largecap Fund            3    181.90
# 11                  ITI Large Cap Fund - Regular Plan            0    163.77
# 7   Mahindra Manulife Large Cap Pragati Yojana - R...            0    108.26
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)  Sharpe Ratio  \
# 19      60.93      11.03      14.23       13.03          0.39
# 21      61.24       9.61      12.48       12.72          0.36
# 1       62.11       9.70      13.23       10.90          0.33
# 15      65.07       8.57      13.26       12.39          0.41
# 6       71.85      11.26      12.00       11.26          0.38
# 25      55.49      11.33      11.91        0.00          0.31
# 3       55.89      10.91      12.50       11.45          0.61
# 23      56.16       9.33       0.00        0.00          0.22
# 11       0.00       0.00       0.00        0.00          0.40
# 7       59.15       0.00       0.00        0.00          0.28
#
#     Turnover ratio(%)  Standard Deviation  Beta
# 19               0.00               20.58  0.93
# 21               0.00               21.12  0.96
# 1              199.00               20.48  0.92
# 15               0.00               19.40  0.85
# 6                0.00               20.46  0.92
# 25              67.68               21.96  0.97
# 3                0.00               18.34  0.81
# 23               0.00               19.76  0.91
# 11               0.00               20.05  0.93
# 7                0.00               22.71  1.01

# %%
# Top 10 low AuM (Cr) regular mutual funds are
mf_tr = regular_mf.loc[(regular_mf['5Y_RTN(%)'] > 0)]
print("Top 10 low 'AuM (Cr)' regular mutual funds are :")
mf_tr[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)',
       'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']].nsmallest(10, 'AuM (Cr)')
# Out:
# Top 10 low 'AuM (Cr)' regular mutual funds are :
#                                 Scheme Name  Crisil Rank  AuM (Cr)  1Y_RTN(%)  \
# 12              Taurus Largecap Equity Fund            2     29.13      49.89
# 17           Baroda Large Cap Fund - Plan A            4     40.90      54.39
# 56                        JM Large Cap Fund            4     54.20      37.15
# 50               Navi Large Cap Equity Fund            3     95.55      56.01
# 63  Indiabulls Bluechip Fund - Regular Plan            1    112.18      46.13
# 38                 Edelweiss Large Cap Fund            4    235.51      57.24
# 57              Invesco India Largecap Fund            2    290.74      48.20
# 3                 PGIM India Large Cap Fund            3    308.64      55.89
# 25           IDBI India Top 100 Equity Fund            4    425.99      55.49
# 59                    LIC MF Large Cap Fund            2    506.24      48.86
#
#     3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)  Sharpe Ratio  Turnover ratio(%)  \
# 12       7.98       9.54        8.05          0.22              84.00
# 17      11.46      12.87        7.64          0.45               0.00
# 56       9.34      10.13        9.18          0.00               0.00
# 50       9.33      12.01        0.00          0.00              66.00
# 63       7.14      11.43        0.00          0.00               0.00
# 38      11.21      13.76       12.97          0.00               0.00
# 57       9.54      12.15       11.56          0.00               0.00
# 3       10.91      12.50       11.45          0.61               0.00
# 25      11.33      11.91        0.00          0.31              67.68
# 59      11.29      12.16       10.44          0.00               0.00
#
#     Standard Deviation  Beta
# 12               20.70  0.93
# 17               20.96  0.97
# 56                0.00  0.00
# 50                0.00  0.00
# 63                0.00  0.00
# 38                0.00  0.00
# 57                0.00  0.00
# 3                18.34  0.81
# 25               21.96  0.97
# 59                0.00  0.00

# %%
# Extracting funds returns 10% in 3year & 5year period which have AuM in between 0Crs to 500Crs
mf_rtn_com = regular_mf.loc[(regular_mf['AuM (Cr)'] > 0) & (regular_mf['AuM (Cr)'] < 500) &
                            (regular_mf['3Y_RTN(%)'] > 10) & (regular_mf['5Y_RTN(%)'] > 10)]
print("No. of funds eturns 10% in 3year & 5year period which have AuM in between 0Crs to 500Crs is:",
      len(mf_rtn_com.index),
      'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds eturns 10% in 3year & 5year period which have AuM in between 0Crs to 500Crs is: 4 Funds
#                        Scheme Name  Crisil Rank  AuM (Cr)  1Y_RTN(%)  \
# 25  IDBI India Top 100 Equity Fund            4    425.99      55.49
# 38        Edelweiss Large Cap Fund            4    235.51      57.24
# 17  Baroda Large Cap Fund - Plan A            4     40.90      54.39
# 3        PGIM India Large Cap Fund            3    308.64      55.89
#
#     3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Sharpe Ratio  Turnover ratio(%)  \
# 25      11.33      11.91        0.00   91.85          0.31              67.68
# 38      11.21      13.76       12.97   39.52          0.00               0.00
# 17      11.46      12.87        7.64  164.49          0.45               0.00
# 3       10.91      12.50       11.45  619.92          0.61               0.00
#
#     Standard Deviation  Beta
# 25               21.96  0.97
# 38                0.00  0.00
# 17               20.96  0.97
# 3                18.34  0.81

# %%
# Extracting funds returns 10% in 3year & 5year period which have AuM in between 500Crs to 1000Crs
mf_rtn_com = regular_mf.loc[(regular_mf['AuM (Cr)'] > 500) & (regular_mf['AuM (Cr)'] < 1000) &
                            (regular_mf['3Y_RTN(%)'] > 10) & (regular_mf['5Y_RTN(%)'] > 10)]
print("No. of funds having '3Y Return', '5Y Return' & '10Y Return' greater than 10% is:", len(mf_rtn_com.index),
      'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds having '3Y Return', '5Y Return' & '10Y Return' greater than 10% is: 4 Funds
#                            Scheme Name  Crisil Rank  AuM (Cr)  1Y_RTN(%)  \
# 33            L&T India Large Cap Fund            3    626.07      52.75
# 36       IDFC Large Cap - Regular Plan            3    714.08      51.96
# 28  Tata Large Cap Fund - Regular Plan            2    892.44      61.50
# 59               LIC MF Large Cap Fund            2    506.24      48.86
#
#     3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)    NAV  Sharpe Ratio  Turnover ratio(%)  \
# 33      10.03      12.31       11.22  46.80           0.0                0.0
# 36      10.41      13.13       10.25  35.62           0.0                0.0
# 28      10.48      12.25       11.43  83.99           0.0                0.0
# 59      11.29      12.16       10.44  12.51           0.0                0.0
#
#     Standard Deviation  Beta
# 33                 0.0   0.0
# 36                 0.0   0.0
# 28                 0.0   0.0
# 59                 0.0   0.0

# %%
# Extracting funds returns 10% in 3year & 5year period which have AuM in between 1000Crs to 1500Crs
mf_rtn_com = regular_mf.loc[(regular_mf['AuM (Cr)'] > 1000) & (regular_mf['AuM (Cr)'] < 1500) &
                            (regular_mf['3Y_RTN(%)'] > 10) & (regular_mf['5Y_RTN(%)'] > 10)]
print("No. of funds returns 10% in 3year & 5year period which have AuM in between 1000Crs to 1500Crs is:",
      len(mf_rtn_com.index),
      'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds returns 10% in 3year & 5year period which have AuM in between 1000Crs to 1500Crs is: 1 Funds
#                    Scheme Name  Crisil Rank  AuM (Cr)  1Y_RTN(%)  3Y_RTN(%)  \
# 53  BNP Paribas Large Cap Fund            3   1029.84      49.69      12.43
#
#     5Y_RTN(%)  10Y_RTN(%)    NAV  Sharpe Ratio  Turnover ratio(%)  \
# 53      12.67       13.53  14.16           0.0               57.0
#
#     Standard Deviation  Beta
# 53                 0.0   0.0

# %%
# Extracting funds returns 10% in 3year & 5year period which have AuM in between 1500 to 20000Crs
mf_rtn_com = regular_mf.loc[(regular_mf['AuM (Cr)'] > 1500) & (regular_mf['AuM (Cr)'] < 20000) &
                            (regular_mf['3Y_RTN(%)'] > 10) & (regular_mf['5Y_RTN(%)'] > 10)]
print("No. of funds returns 10% in 3year & 5year period which have AuM in between 1500Crs to 20000Crs is:",
      len(mf_rtn_com.index),
      'Funds')
mf_rtn_com[['Scheme Name', 'Crisil Rank', 'AuM (Cr)', '1Y_RTN(%)','3Y_RTN(%)', '5Y_RTN(%)', '10Y_RTN(%)', 'NAV',
           'Sharpe Ratio', 'Turnover ratio(%)', 'Standard Deviation', 'Beta']]
# Out:
# No. of funds returns 10% in 3year & 5year period which have AuM in between 1500Crs to 20000Crs is: 4 Funds
#                                           Scheme Name  Crisil Rank  AuM (Cr)  \
# 43                        UTI Mastershare Unit Scheme            5   7734.48
# 65                                Kotak Bluechip Fund            5   2411.04
# 39  Canara Robeco Bluechip Equity Fund - Regular Plan            5   2476.82
# 6                        Franklin India Bluechip Fund            4   5910.59
#
#     1Y_RTN(%)  3Y_RTN(%)  5Y_RTN(%)  10Y_RTN(%)     NAV  Sharpe Ratio  \
# 43      60.32      11.91      13.64       11.88   40.94          0.00
# 65      60.58      12.35      13.35       12.07   12.43          0.00
# 39      55.13      15.81      16.34       13.23   32.53          0.00
# 6       71.85      11.26      12.00       11.26  220.12          0.38
#
#     Turnover ratio(%)  Standard Deviation  Beta
# 43                0.0                0.00  0.00
# 65                0.0                0.00  0.00
# 39                0.0                0.00  0.00
# 6                 0.0               20.46  0.92
