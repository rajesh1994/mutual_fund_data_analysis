# %%
# Importing respective modules
import pandas as pd

# %% [markdown]
# ## Mid Cap Fund
#
# These mutual funds select stocks for investment from the mid cap category – stocks ranked between 100 to 250 by size (market capitalization).Larger stocks are expected to be less risky whereas smaller stocks may have higher potential to grow .

# %% [markdown]
# ## Exctracting Mid Cap Mutual Fund's Historical Investment Returns Data
#
# Data in this table: Get Absolute historical returns for ₹1000 investment. If 1Y column value is 1234.5 that means, your ₹1000 investment 1 year back would have grown to ₹1234.5.

# %%
mc_lump_sum_rtn = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/returns/mid-cap-fund.html")
df1 = pd.DataFrame(mc_lump_sum_rtn[0])

# %%
#Renaming historical returns column names
df1.rename({'1W': '1W_RTN(%)', '1M': '1M_RTN(%)', '3M': '3M_RTN(%)', '6M': '6M_RTN(%)',
                 'YTD': 'YTD_RTN(%)', '1Y': '1Y_RTN(%)', '2Y': '2Y_RTN(%)', '3Y': '3Y_RTN(%)',
                 '5Y': '5Y_RTN(%)', '10Y': '10Y_RTN(%)'
          }, axis=1, inplace=True)
print("Shape of the dataframe:", df1.shape)
df1.head()
# Out:
# Shape of the dataframe: (54, 13)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0  Quant Mid Cap Fund - Direct Plan - GrowthMid C...           -     35.85
# 1            Quant Mid Cap Fund - GrowthMid Cap Fund           1     35.85
# 2  Edelweiss Mid Cap Fund - Direct Plan - GrowthM...           4   1245.66
# 3  Edelweiss Mid Cap Fund - Regular Plan - Growth...           3   1245.66
# 4  Baroda Mid-cap Fund - Plan B (Direct) - Growth...           3     55.70
#
#   1W_RTN(%) 1M_RTN(%) 3M_RTN(%) 6M_RTN(%) YTD_RTN(%) 1Y_RTN(%) 2Y_RTN(%)  \
# 0     5.65%     6.90%    21.96%    49.22%     24.96%    95.42%    37.50%
# 1     5.59%     6.67%    21.30%    47.99%     24.06%    92.14%    35.26%
# 2     2.40%     1.43%     6.48%    37.51%     20.27%    86.30%    28.71%
# 3     2.37%     1.30%     6.13%    36.57%     19.67%    83.55%    26.73%
# 4     2.16%     1.43%     7.10%    28.68%     14.91%    78.25%    25.14%
#
#   3Y_RTN(%) 5Y_RTN(%) 10Y_RTN(%)
# 0    20.75%    17.25%          -
# 1    19.22%    16.32%     13.24%
# 2    12.92%    18.31%          -
# 3    11.23%    16.91%     18.20%
# 4    10.38%    15.96%          -

# %% [markdown]
# ## Exctracting Mid Cap Mutual Fund's Monthly Returns Data
#
# Data in this table: Get monthly returns. If Jan month column value is 5.4% that means, fund has given 5.4% returns in Jan month.

# %%
mc_monthly_rtn = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/monthly-returns/mid-cap-fund.html")
df2 = pd.DataFrame(mc_monthly_rtn[0])

# %%
#Renaming df1 column names
df1.rename({"Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)",
            'MTD': 'MTD_RTN(%)', "Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)",
            "Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)"
          }, axis=1, inplace=True)

print("Shape of the dataframe:", df2.shape)
df2.head()
# Out:
# Shape of the dataframe: (54, 14)
#                                          Scheme Name Crisil Rank    MTD  \
# 0      BNP Paribas Mid Cap Fund - GrowthMid Cap Fund           5  0.63%
# 1  BNP Paribas Mid Cap Fund - Direct Plan - Growt...           5  0.67%
# 2              Axis Midcap Fund - GrowthMid Cap Fund           4  0.91%
# 3  Axis Midcap Fund - Direct Plan - GrowthMid Cap...           4  0.93%
# 4  Aditya Birla Sun Life Midcap Fund - Regular Pl...           2  2.13%
#
#   Apr'21 Mar'21  Feb'21  Jan'21 Dec'20  Nov'20  Oct'20 Sep'20 Aug'20 Jul'20  \
# 0  0.58%  0.32%  10.40%  -0.92%  5.69%  11.51%  -1.03%  1.05%  6.66%  4.78%
# 1  0.70%  0.44%  10.52%  -0.80%  5.83%  11.63%  -0.91%  1.17%  6.79%  4.91%
# 2  0.27%  1.07%   6.24%  -2.70%  4.53%  11.43%   0.23%  2.81%  4.83%  4.23%
# 3  0.38%  1.19%   6.36%  -2.60%  4.67%  11.54%   0.36%  2.94%  4.94%  4.38%
# 4  0.25%  0.75%   7.15%  -1.83%  5.22%  11.82%  -0.49%  1.10%  7.69%  4.62%
#
#   Jun'20
# 0  5.94%
# 1  6.06%
# 2  3.45%
# 3  3.55%
# 4  8.69%

# %% [markdown]
# ## Exctracting Mid Cap Mutual Fund's Quarterly Returns Data
#
# Data in this table: Get quarterly returns. If Q1 column value is 5.4% that means, fund has given 5.4% returns from 1st Jan to 31st Mar.

# %%
mc_quarterly_rtn = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/quarterly-returns/mid-cap-fund.html")
df3 = pd.DataFrame(mc_quarterly_rtn[0])

# %%
print("Shape of the dataframe:", df3.shape)
df3.head()
# Out:
# Shape of the dataframe: (54, 14)
#                                          Scheme Name Crisil Rank     QTD  \
# 0  ITI Mid Cap Fund - Regular Plan - GrowthMid Ca...           -   0.85%
# 1  ITI Mid Cap Fund - Direct Plan - GrowthMid Cap...           -   1.12%
# 2  Taurus Discovery (Midcap) Fund - GrowthMid Cap...           3   3.25%
# 3  Taurus Discovery (Midcap) Fund - Direct Plan -...           3   3.26%
# 4     Franklin India Prima Fund - GrowthMid Cap Fund           2  -0.23%
#
#     Q1'21   Q4'20   Q3'20   Q2'20    Q1'20  Q4'19   Q3'19   Q2'19  Q1'19  \
# 0       -       -       -       -        -      -       -       -      -
# 1       -       -       -       -        -      -       -       -      -
# 2  10.72%  13.75%  14.39%  21.21%  -19.63%  6.35%  -2.79%  -2.88%  1.98%
# 3  10.83%  13.84%  14.49%  21.36%  -19.56%  6.45%  -2.68%  -2.75%  2.13%
# 4   9.89%  22.34%  10.14%  22.23%  -28.15%  4.86%  -3.20%  -1.68%  4.90%
#
#    Q4'18   Q3'18
# 0      -       -
# 1      -       -
# 2  1.95%  -4.67%
# 3  2.04%  -4.48%
# 4  3.44%  -4.22%

# %% [markdown]
# ## Exctracting Mid Cap Mutual Fund's Annual Investment Returns Data
#
# Data in this table: Get annual returns. If 2018 year column value is 5.4% that means, fund has given 5.4% returns from 1st Jan to 31st Dec/Last date.

# %%
mc_annual_rtn = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/annual-returns/mid-cap-fund.html")
df4 = pd.DataFrame(mc_annual_rtn[0])

# %%
#Renaming yearly returns column names
df4.rename({'2020': '2020_RTN(%)', '2019': '2019_RTN(%)', '2018': '2018_RTN(%)', '2017': '2017_RTN(%)',
                 '2016': '2016_RTN(%)', '2015': '2015_RTN(%)', '2014': '2014_RTN(%)', '2013': '2013_RTN(%)',
                 '2012': '2012_RTN(%)', '2011': '2011_RTN(%)', '2010': '2010_RTN(%)'
               }, axis=1, inplace=True)

print("Shape of the dataframe:", df4.shape)
df4.head()
# Out:
# Shape of the dataframe: (54, 14)
#                                          Scheme Name Crisil Rank     YTD  \
# 0  ITI Mid Cap Fund - Regular Plan - Growth Mid C...           -   0.99%
# 1  ITI Mid Cap Fund - Direct Plan - Growth Mid Ca...           -   1.43%
# 2  Taurus Discovery (Midcap) Fund - Growth Mid Ca...           3  15.72%
# 3  Taurus Discovery (Midcap) Fund - Direct Plan -...           3  15.86%
# 4    Franklin India Prima Fund - Growth Mid Cap Fund           2  10.60%
#
#   2020_RTN(%) 2019_RTN(%) 2018_RTN(%) 2017_RTN(%) 2016_RTN(%) 2015_RTN(%)  \
# 0           -           -           -           -           -           -
# 1           -           -           -           -           -           -
# 2      24.97%       1.26%      -6.79%      46.13%       2.60%       7.42%
# 3      25.75%       1.77%      -6.35%      46.63%       3.24%       8.20%
# 4      17.49%       3.03%      -8.87%      39.70%       7.59%       6.50%
#
#   2014_RTN(%) 2013_RTN(%) 2012_RTN(%) 2011_RTN(%) 2010_RTN(%)
# 0           -           -           -           -           -
# 1           -           -           -           -           -
# 2      59.99%      -0.40%      49.79%     -30.45%      13.99%
# 3      60.57%      -0.62%           -           -           -
# 4      77.67%       6.55%      44.42%     -22.06%      19.11%

# %% [markdown]
# ## Exctracting Mid Cap Mutual Fund's Rank Within Category Data
#
# Data in this table: Get performance rank within category. If 1Y column value is 3/45 that means, Fund ranked 3rd in terms of performance out of 45 funds in that category.

# %%
mc_rank_in_category = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/ranks/mid-cap-fund.html")
df5 = pd.DataFrame(mc_rank_in_category[0])

# %%
#Renaming df5 column names
df5.rename({'1W': '1W_Rank', '1M': '1M_Rank', '3M': '3M_Rank', '6M': '6M_Rank', 'YTD': 'YTD_Rank',
            '1Y': '1Y_Rank', '2Y': '2Y_Rank', '3Y': '3Y_Rank', '5Y': '5Y_Rank', '10Y': '10Y_Rank'
          }, axis=1, inplace=True)

print("Shape of the dataframe:", df5.shape)
df5.head()
# Out:
# Shape of the dataframe: (52, 12)
#                                          Scheme Name Crisil Rank 1W_Rank  \
# 0  PGIM India Midcap Opportunities Fund - Direct ...           5    9/27
# 1  PGIM India Midcap Opportunities Fund - GrowthM...           5   10/28
# 2  SBI Magnum Midcap Fund - Regular Plan - Growth...           4   25/28
# 3  Mirae Asset Midcap Fund - Direct Plan - Growth...           -    6/27
# 4  Mirae Asset Midcap Fund - Regular Plan - Growt...           -    7/28
#
#   1M_Rank 3M_Rank 6M_Rank YTD_Rank 1Y_Rank 2Y_Rank 3Y_Rank 5Y_Rank 10Y_Rank
# 0    3/27    3/26    3/26     2/26    1/26    1/23    2/23    1/21      0/0
# 1    3/28    4/27    3/27     2/27    1/27    1/24    2/24    2/22    19/21
# 2   16/28    9/27    2/27     6/27    2/27    7/24   13/24   19/22     6/20
# 3    4/27   16/26    5/26     4/26    2/26     0/0     0/0     0/0      0/0
# 4    4/28   17/27    6/27     4/27    3/27     0/0     0/0     0/0      0/0

# %% [markdown]
# ## Exctracting Mid Cap Mutual Fund's Risk Ratios Data
#
# Data in this table: Get values of risk ratios calculated on daily returns for last 3 years.

# %%
mc_risk_ratio = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/risk-ratios/mid-cap-fund.html")
df6 = pd.DataFrame(mc_risk_ratio[0])

# %%
#Droping the 'Category' column
df6.drop('Category', inplace=True, axis=1)
print("Shape of the dataframe:", df6.shape)
df6.head()
# Out:
# Shape of the dataframe: (21, 8)
#                                          Scheme Name  Crisil Rank  AuM (Cr)  \
# 0            Taurus Discovery (Midcap) Fund - Growth            3     67.47
# 1                 Franklin India Prima Fund - Growth            2   7194.82
# 2              ICICI Prudential MidCap Fund - Growth            3   2375.17
# 3                     Kotak Emerging Equity - Growth            4  11430.03
# 4  Mahindra Manulife Mid Cap Unnati Yojana - Regu...            3    649.85
#
#    Standard Deviation  Beta  Sharpe Ratio  Jension's Alpha  Treynor's Ratio
# 0               18.78  0.80          0.40             3.57             0.09
# 1               18.65  0.80          0.31             1.86             0.07
# 2               20.08  0.86          0.28             1.27             0.06
# 3               18.50  0.80          0.51             4.69             0.12
# 4               18.12  0.81          0.48             4.26             0.11

# %% [markdown]
# ## Exctracting Mid Cap Mutual Fund's Portfolio Data
#
# Data in this table: Compare how schemes have invested money across various asset class and number of instruments.

# %%
mc_portfolio = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/portfolioassets/mid-cap-fund.html")
df7 = pd.DataFrame(mc_portfolio[0])

# %%
#Renaming SIP returns column names
df7.rename({'Turnover ratio': 'Turnover ratio(%)'}, axis=1, inplace=True)

print("Shape of the dataframe:", df7.shape)
df7.head()
# Out:
# Shape of the dataframe: (54, 10)
#                                          Scheme Name Crisil Rank  \
# 0            Quant Mid Cap Fund - GrowthMid Cap Fund           1
# 1  Quant Mid Cap Fund - Direct Plan - GrowthMid C...           -
# 2  UTI Mid Cap Fund - Direct Plan - GrowthMid Cap...           3
# 3              UTI Mid Cap Fund - GrowthMid Cap Fund           4
# 4  Invesco India Mid Cap Fund - Direct Plan - Gro...           3
#
#   Turnover ratio(%) % Equity Holding  No of stocks in portfolio  \
# 0           653.00%          101.02%                         26
# 1           653.00%          101.02%                         26
# 2                 -           98.87%                         72
# 3                 -           98.87%                         72
# 4            79.00%           98.36%                         45
#
#   % Debt Holding No of instruments in portfolio % MF Holding % Cash Holding  \
# 0              -                              -            -         -1.02%
# 1              -                              -            -         -1.02%
# 2              -                              -        0.09%          1.04%
# 3              -                              -        0.09%          1.04%
# 4              -                              -            -          1.64%
#
#   % Other Holding
# 0               -
# 1               -
# 2               -
# 3               -
# 4               -

# %% [markdown]
# ## Exctracting Mid Cap Mutual Fund's Latest NAV Data
#
# Data in this table: Get the latest values of NAV for the mutual funds.

# %%
mc_nav = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/navs/mid-cap-fund.html")
df8 = pd.DataFrame(mc_nav[0])

# %%
df8.rename({'1D Change' : '1D Change(%)'}, axis=1, inplace=True)
print("Shape of the dataframe:", df8.shape)
df8.head()
# Out:
# Shape of the dataframe: (54, 10)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0  Nippon India Growth Fund - Direct Plan - Growt...           3   9123.18
# 1      Nippon India Growth Fund - GrowthMid Cap Fund           3   9123.18
# 2  Aditya Birla Sun Life Midcap Fund - Direct Pla...           2   2697.22
# 3  Aditya Birla Sun Life Midcap Fund - Regular Pl...           2   2697.22
# 4  Sundaram Mid Cap Fund - Direct Plan - GrowthMi...           1   6152.10
#
#          NAV 1D Change(%)   NAV Date   52W High 52WH as on   52W Low  \
# 0  1707.9386        0.65%  10-May-21  1719.1999  04-Mar-21  907.5022
# 1  1611.8294        0.64%  10-May-21  1624.7191  04-Mar-21  862.3686
# 2   390.6200        0.98%  10-May-21   390.6200  10-May-21  210.1800
# 3   363.6100        0.97%  10-May-21   363.6100  10-May-21  197.4700
# 4   608.8778        0.42%  10-May-21   635.6429  04-Mar-21  347.4057
#
#   52WL as on
# 0  18-May-20
# 1  18-May-20
# 2  18-May-20
# 3  18-May-20
# 4  18-May-20

# %% [markdown]
# ## Exctracting Mid Cap Mutual Fund's SIP Returns Data
#
# Data in this table: Get absolute SIP returns. If 1Y column value is 10%, that means fund has given 10% returns on your SIP investments started 1 year back from latest NAV date.

# %%
mc_sip_rtns = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/sip-returns/mid-cap-fund.html")
df9 = pd.DataFrame(mc_sip_rtns[0])

# %%
#Renaming SIP returns column names
df9.rename({'1Y': '1Y_SIP_RTN(%)', '2Y': '2Y_SIP_RTN(%)', '3Y': '3Y_SIP_RTN(%)',
                  '5Y': '5Y_SIP_RTN(%)', '10Y': '10Y_SIP_RTN(%)', 'YTD' : 'YTD_SIP_RTN(%)'
           }, axis=1, inplace=True)

print("Shape of the dataframe:", df9.shape)
df9.head()
# Out:
# Shape of the dataframe: (52, 8)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0  Quant Mid Cap Fund - Direct Plan - GrowthMid C...           -     35.85
# 1            Quant Mid Cap Fund - GrowthMid Cap Fund           1     35.85
# 2  PGIM India Midcap Opportunities Fund - Direct ...           5   1107.77
# 3  PGIM India Midcap Opportunities Fund - GrowthM...           5   1107.77
# 4  Mirae Asset Midcap Fund - Direct Plan - Growth...           -   4539.66
#
#   1Y_SIP_RTN(%) 2Y_SIP_RTN(%) 3Y_SIP_RTN(%) 5Y_SIP_RTN(%) 10Y_SIP_RTN(%)
# 0        48.34%        68.60%        72.16%        84.85%              -
# 1        46.83%        65.40%        67.93%        79.12%        132.94%
# 2        46.83%        72.19%        78.34%        87.53%              -
# 3        45.20%        68.73%        73.41%        79.42%              -
# 4        41.51%             -             -             -              -

# %%
df_final = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9],axis=1,sort=False)
print("Shape of the dataframe:", df_final.shape)
# Out:
# Shape of the dataframe: (54, 103)

# %%
# Remove duplicate columns by name in Pandas
df_final = df_final.loc[:,~df_final.columns.duplicated()]

# Removing spaces in the column names
#df_final.columns = df_final.columns.str.replace(' ','_')

print("Shape of the dataframe:", df_final.shape)
df_final.head()
# Out:
# Shape of the dataframe: (54, 84)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0  Quant Mid Cap Fund - Direct Plan - GrowthMid C...           -     35.85
# 1            Quant Mid Cap Fund - GrowthMid Cap Fund           1     35.85
# 2  Edelweiss Mid Cap Fund - Direct Plan - GrowthM...           4   1245.66
# 3  Edelweiss Mid Cap Fund - Regular Plan - Growth...           3   1245.66
# 4  Baroda Mid-cap Fund - Plan B (Direct) - Growth...           3     55.70
#
#   1W_RTN(%) 1M_RTN(%) 3M_RTN(%) 6M_RTN(%) YTD_RTN(%) 1Y_RTN(%) 2Y_RTN(%)  ...  \
# 0     5.65%     6.90%    21.96%    49.22%     24.96%    95.42%    37.50%  ...
# 1     5.59%     6.67%    21.30%    47.99%     24.06%    92.14%    35.26%  ...
# 2     2.40%     1.43%     6.48%    37.51%     20.27%    86.30%    28.71%  ...
# 3     2.37%     1.30%     6.13%    36.57%     19.67%    83.55%    26.73%  ...
# 4     2.16%     1.43%     7.10%    28.68%     14.91%    78.25%    25.14%  ...
#
#     NAV Date   52W High 52WH as on   52W Low 52WL as on 1Y_SIP_RTN(%)  \
# 0  10-May-21  1719.1999  04-Mar-21  907.5022  18-May-20        48.34%
# 1  10-May-21  1624.7191  04-Mar-21  862.3686  18-May-20        46.83%
# 2  10-May-21   390.6200  10-May-21  210.1800  18-May-20        46.83%
# 3  10-May-21   363.6100  10-May-21  197.4700  18-May-20        45.20%
# 4  10-May-21   635.6429  04-Mar-21  347.4057  18-May-20        41.51%
#
#   2Y_SIP_RTN(%) 3Y_SIP_RTN(%) 5Y_SIP_RTN(%) 10Y_SIP_RTN(%)
# 0        68.60%        72.16%        84.85%              -
# 1        65.40%        67.93%        79.12%        132.94%
# 2        72.19%        78.34%        87.53%              -
# 3        68.73%        73.41%        79.42%              -
# 4             -             -             -              -
#
# [5 rows x 84 columns]

# %%
#Exporting the consolidated elss mf data as a  csv file
#print("Shape of the dataframe:", df_final.shape)
#df_final.to_csv('mc_mf_data('+ str(pd.to_datetime('today').strftime('%d-%b-%Y %H:%M:%S')) + ').csv',
#               index=False)

#Exporting the elss mf data columns with its datatype as a  csv file
#df_dtypes.to_csv('elss_mf_col_data_types('+ str(pd.to_datetime('today').strftime('%d-%b-%Y %H:%M:%S')) + '.csv)')
