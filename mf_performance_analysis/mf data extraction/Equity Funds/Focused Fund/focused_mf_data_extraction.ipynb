# %%
# Importing respective modules
import pandas as pd

# %% [markdown]
# ## Focused Fund
#
# These mutual funds invest in stocks but restrict the number of stocks in the portfolio to a maximum of 30.

# %% [markdown]
# ## Exctracting Focused Mutual Fund's Historical Investment Returns Data
#
# Data in this table: Get Absolute historical returns for ₹1000 investment. If 1Y column value is 1234.5 that means, your ₹1000 investment 1 year back would have grown to ₹1234.5.

# %%
focused_lump_sum_rtn = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/returns/focused-fund.html")
df1 = pd.DataFrame(focused_lump_sum_rtn[0])

# %%
#Renaming historical returns column names
df1.rename({'1W': '1W_RTN(%)', '1M': '1M_RTN(%)', '3M': '3M_RTN(%)', '6M': '6M_RTN(%)',
                 'YTD': 'YTD_RTN(%)', '1Y': '1Y_RTN(%)', '2Y': '2Y_RTN(%)', '3Y': '3Y_RTN(%)',
                 '5Y': '5Y_RTN(%)', '10Y': '10Y_RTN(%)'
          }, axis=1, inplace=True)
print("Shape of the dataframe:", df1.shape)
df1.head()
# Out:
# Shape of the dataframe: (50, 13)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0  Quant Focused Fund - Direct Plan - GrowthFocus...           -     12.12
# 1            Quant Focused Fund - GrowthFocused Fund           -     12.12
# 2  ICICI Prudential Focused Equity Fund - Direct ...           4   1316.11
# 3  ICICI Prudential Focused Equity Fund - Regular...           4   1316.11
# 4  Franklin India Focused Equity Fund - Direct - ...           3   7359.87
#
#   1W_RTN(%) 1M_RTN(%) 3M_RTN(%) 6M_RTN(%) YTD_RTN(%) 1Y_RTN(%) 2Y_RTN(%)  \
# 0     5.35%     6.08%    18.97%    46.37%     26.48%    84.77%    29.83%
# 1     5.24%     5.84%    18.30%    44.85%     25.52%    81.23%    27.71%
# 2     3.55%     3.29%     2.77%    31.28%     14.42%    66.79%    19.13%
# 3     3.54%     3.18%     2.48%    30.49%     13.92%    64.79%    17.84%
# 4     2.94%     2.96%     1.83%    31.90%     16.62%    77.02%    17.74%
#
#   3Y_RTN(%) 5Y_RTN(%) 10Y_RTN(%)
# 0    16.59%    16.82%          -
# 1    15.09%    15.87%     16.65%
# 2    13.84%    14.73%          -
# 3    12.62%    13.47%     11.52%
# 4    13.28%    15.25%          -

# %% [markdown]
# ## Exctracting Focused Mutual Fund's Monthly Returns Data
#
# Data in this table: Get monthly returns. If Jan month column value is 5.4% that means, fund has given 5.4% returns in Jan month.

# %%
focused_monthly_rtn = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/monthly-returns/focused-fund.html")
df2 = pd.DataFrame(focused_monthly_rtn[0])

# %%
#Renaming df1 column names
df1.rename({"Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)",
            'MTD': 'MTD_RTN(%)', "Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)",
            "Apr'21": "Apr'21(%)", "Apr'21": "Apr'21(%)"
          }, axis=1, inplace=True)

print("Shape of the dataframe:", df2.shape)
df2.head()
# Out:
# Shape of the dataframe: (50, 14)
#                                          Scheme Name Crisil Rank    MTD  \
# 0  Franklin India Focused Equity Fund - GrowthFoc...           3  3.23%
# 1  Franklin India Focused Equity Fund - Direct - ...           3  3.26%
# 2  ICICI Prudential Focused Equity Fund - Direct ...           4  4.20%
# 3  ICICI Prudential Focused Equity Fund - Regular...           4  4.17%
# 4  Principal Focused Multicap Fund - GrowthFocuse...           4  1.51%
#
#    Apr'21  Mar'21 Feb'21  Jan'21 Dec'20  Nov'20  Oct'20  Sep'20 Aug'20 Jul'20  \
# 0  -0.92%  -2.67%  6.33%   1.14%  6.92%  14.93%   4.23%  -7.81%  4.97%  0.05%
# 1  -0.86%  -2.60%  6.40%   1.21%  7.00%  15.00%   4.29%  -7.75%  5.04%  0.12%
# 2  -1.24%  -0.53%  4.35%  -0.66%  6.66%  10.53%  -0.03%  -3.33%  1.99%  6.96%
# 3  -1.32%  -0.60%  4.27%  -0.77%  6.56%  10.43%  -0.13%  -3.43%  1.88%  6.86%
# 4   0.79%  -1.41%  4.90%  -2.55%  6.30%  12.83%   0.27%  -0.80%  2.48%  3.90%
#
#   Jun'20
# 0  6.64%
# 1  6.71%
# 2  3.98%
# 3  3.88%
# 4  4.23%

# %% [markdown]
# ## Exctracting Focused Mutual Fund's Quarterly Returns Data
#
# Data in this table: Get quarterly returns. If Q1 column value is 5.4% that means, fund has given 5.4% returns from 1st Jan to 31st Mar.

# %%
focused_quarterly_rtn = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/quarterly-returns/focused-fund.html")
df3 = pd.DataFrame(focused_quarterly_rtn[0])

# %%
print("Shape of the dataframe:", df3.shape)
df3.head()
# Out:
# Shape of the dataframe: (50, 14)
#                                          Scheme Name Crisil Rank    QTD  \
# 0  Franklin India Focused Equity Fund - GrowthFoc...           3  2.28%
# 1  Franklin India Focused Equity Fund - Direct - ...           3  2.37%
# 2  ICICI Prudential Focused Equity Fund - Direct ...           4  2.91%
# 3  ICICI Prudential Focused Equity Fund - Regular...           4  2.79%
# 4  Principal Focused Multicap Fund - GrowthFocuse...           4  2.31%
#
#     Q1'21   Q4'20   Q3'20   Q2'20    Q1'20  Q4'19   Q3'19   Q2'19  Q1'19  \
# 0  11.62%  30.57%  -2.42%  25.47%  -31.03%  7.93%  -6.93%   2.78%  7.91%
# 1  11.87%  30.84%  -2.22%  25.73%  -30.88%  8.17%  -6.73%   3.02%  8.20%
# 2   8.36%  19.77%   6.40%  29.45%  -22.02%  2.17%  -4.96%  -0.58%  5.06%
# 3   8.05%  19.42%   6.05%  29.15%  -22.23%  1.93%  -5.22%  -0.85%  4.79%
# 4   7.42%  21.46%   6.46%  18.56%  -20.53%  8.18%  -1.43%   2.35%  2.30%
#
#     Q4'18  Q3'18
# 0   1.79%  0.03%
# 1   2.06%  0.30%
# 2  -6.37%  5.72%
# 3  -6.64%  5.45%
# 4   1.41%  0.28%

# %% [markdown]
# ## Exctracting Focused Mutual Fund's Annual Investment Returns Data
#
# Data in this table: Get annual returns. If 2018 year column value is 5.4% that means, fund has given 5.4% returns from 1st Jan to 31st Dec/Last date.

# %%
focused_annual_rtn = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/annual-returns/focused-fund.html")
df4 = pd.DataFrame(focused_annual_rtn[0])

# %%
#Renaming yearly returns column names
df4.rename({'2020': '2020_RTN(%)', '2019': '2019_RTN(%)', '2018': '2018_RTN(%)', '2017': '2017_RTN(%)',
                 '2016': '2016_RTN(%)', '2015': '2015_RTN(%)', '2014': '2014_RTN(%)', '2013': '2013_RTN(%)',
                 '2012': '2012_RTN(%)', '2011': '2011_RTN(%)', '2010': '2010_RTN(%)'
               }, axis=1, inplace=True)

print("Shape of the dataframe:", df4.shape)
df4.head()
# Out:
# Shape of the dataframe: (50, 14)
#                                          Scheme Name Crisil Rank    YTD  \
# 0  BNP Paribas Focused 25 Equity Fund - Growth Fo...           2  4.42%
# 1  BNP Paribas Focused 25 Equity Fund - Direct Pl...           2  5.02%
# 2  IDFC Focused Equity Fund - Regular Plan - Grow...           2  3.83%
# 3  IDFC Focused Equity Fund - Direct Plan - Growt...           2  4.32%
# 4         Axis Focused 25 Fund - Growth Focused Fund           3  4.28%
#
#   2020_RTN(%) 2019_RTN(%) 2018_RTN(%) 2017_RTN(%) 2016_RTN(%) 2015_RTN(%)  \
# 0      15.36%      13.14%     -11.69%       3.47%           -           -
# 1      17.01%      14.59%     -10.46%       3.86%           -           -
# 2      15.41%       9.28%     -12.39%      54.42%       1.30%      -4.90%
# 3      16.96%      10.85%     -10.97%      56.85%       3.10%      -3.44%
# 4      20.88%      15.37%       1.32%      45.15%       4.20%       4.03%
#
#   2014_RTN(%) 2013_RTN(%) 2012_RTN(%) 2011_RTN(%) 2010_RTN(%)
# 0           -           -           -           -           -
# 1           -           -           -           -           -
# 2      32.39%       2.16%      20.79%     -20.57%      16.47%
# 3      33.06%       2.34%           -           -           -
# 4      38.98%       4.46%      15.10%           -           -

# %% [markdown]
# ## Exctracting Focused Mutual Fund's Rank Within Category Data
#
# Data in this table: Get performance rank within category. If 1Y column value is 3/45 that means, Fund ranked 3rd in terms of performance out of 45 funds in that category.

# %%
focused_rank_in_category = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/ranks/focused-fund.html")
df5 = pd.DataFrame(focused_rank_in_category[0])

# %%
#Renaming df5 column names
df5.rename({'1W': '1W_Rank', '1M': '1M_Rank', '3M': '3M_Rank', '6M': '6M_Rank', 'YTD': 'YTD_Rank',
            '1Y': '1Y_Rank', '2Y': '2Y_Rank', '3Y': '3Y_Rank', '5Y': '5Y_Rank', '10Y': '10Y_Rank'
          }, axis=1, inplace=True)

print("Shape of the dataframe:", df5.shape)
df5.head()
# Out:
# Shape of the dataframe: (44, 12)
#                                          Scheme Name Crisil Rank 1W_Rank  \
# 0            Quant Focused Fund - GrowthFocused Fund           -    1/25
# 1  Quant Focused Fund - Direct Plan - GrowthFocus...           -    1/25
# 2  Nippon India Focused Equity Fund - GrowthFocus...           5   14/25
# 3  Nippon India Focused Equity Fund - Direct Plan...           5   14/25
# 4  Mirae Asset Focused Fund - Direct Plan - Growt...           -   13/25
#
#   1M_Rank 3M_Rank 6M_Rank YTD_Rank 1Y_Rank 2Y_Rank 3Y_Rank 5Y_Rank 10Y_Rank
# 0    1/25    1/25    1/24     1/25    1/22    1/18    2/17    3/15     2/12
# 1    1/25    1/25    1/24     1/25    1/22    1/18    2/17    4/15      0/0
# 2   11/25    8/25    2/24     3/25    2/22    6/18   10/17    6/15     4/12
# 3   11/25    9/25    2/24     3/25    2/22    8/18   10/17    3/15      0/0
# 4   18/25   10/25    7/24     9/25    3/22     0/0     0/0     0/0      0/0

# %% [markdown]
# ## Exctracting Focused Mutual Fund's Risk Ratios Data
#
# Data in this table: Get values of risk ratios calculated on daily returns for last 3 years.

# %%
focused_risk_ratio = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/risk-ratios/focused-fund.html")
df6 = pd.DataFrame(focused_risk_ratio[0])

# %%
#Droping the 'Category' column
df6.drop('Category', inplace=True, axis=1)
print("Shape of the dataframe:", df6.shape)
df6.head()
# Out:
# Shape of the dataframe: (17, 8)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0        Franklin India Focused Equity Fund - Growth           3   7359.87
# 1  ICICI Prudential Focused Equity Fund - Regular...           4   1316.11
# 2           Principal Focused Multicap Fund - Growth           4    539.05
# 3                      HDFC Focused 30 Fund - Growth           1    656.96
# 4                           JM Core 11 Fund - Growth           1     46.12
#
#    Standard Deviation  Beta  Sharpe Ratio  Jension's Alpha  Treynor's Ratio
# 0               22.37  0.93          0.44             1.20             0.11
# 1               18.58  0.80          0.45             1.58             0.11
# 2               19.77  0.89          0.58             3.91             0.13
# 3               21.58  0.96          0.09            -6.09             0.02
# 4               22.76  0.93          0.15            -5.88             0.04

# %% [markdown]
# ## Exctracting Focused Mutual Fund's Portfolio Data
#
# Data in this table: Compare how schemes have invested money across various asset class and number of instruments.

# %%
focused_portfolio = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/portfolioassets/focused-fund.html")
df7 = pd.DataFrame(focused_portfolio[0])

# %%
#Renaming SIP returns column names
df7.rename({'Turnover ratio': 'Turnover ratio(%)'}, axis=1, inplace=True)

print("Shape of the dataframe:", df7.shape)
df7.head()
# Out:
# Shape of the dataframe: (50, 10)
#                                          Scheme Name Crisil Rank  \
# 0  Quant Focused Fund - Direct Plan - GrowthFocus...           -
# 1            Quant Focused Fund - GrowthFocused Fund           -
# 2  Motilal Oswal Focused 25 Fund - GrowthFocused ...           3
# 3  Motilal Oswal Focused 25 Fund - Direct Plan - ...           3
# 4  DSP Focus Fund - Regular Plan - GrowthFocused ...           2
#
#   Turnover ratio(%) % Equity Holding  No of stocks in portfolio  \
# 0           841.00%          100.29%                         20
# 1           841.00%          100.29%                         20
# 2                 -           99.71%                         23
# 3                 -           99.71%                         23
# 4                 -           99.39%                         26
#
#   % Debt Holding No of instruments in portfolio % MF Holding % Cash Holding  \
# 0              -                              -            -         -0.29%
# 1              -                              -            -         -0.29%
# 2          0.02%                              1            -          0.27%
# 3          0.02%                              1            -          0.27%
# 4              -                              -            -          0.61%
#
#   % Other Holding
# 0               -
# 1               -
# 2               -
# 3               -
# 4               -

# %% [markdown]
# ## Exctracting Focused Mutual Fund's Latest NAV Data
#
# Data in this table: Get the latest values of NAV for the mutual funds.

# %%
focused_nav = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/navs/focused-fund.html")
df8 = pd.DataFrame(focused_nav[0])

# %%
df8.rename({'1D Change' : '1D Change(%)'}, axis=1, inplace=True)
print("Shape of the dataframe:", df8.shape)
df8.head()
# Out:
# Shape of the dataframe: (50, 10)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0  SBI Focused Equity Fund - Direct Plan - Growth...           4  14766.83
# 1  SBI Focused Equity Fund - Regular Plan - Growt...           4  14766.83
# 2  Sundaram Select Focus - Direct Plan - GrowthFo...           3   1217.67
# 3         Sundaram Select Focus - GrowthFocused Fund           3   1217.67
# 4  HDFC Focused 30 Fund - Direct Plan - GrowthFoc...           1    656.96
#
#         NAV 1D Change(%)   NAV Date  52W High 52WH as on   52W Low 52WL as on
# 0  209.4941        1.06%  10-May-21  209.4941  10-May-21  129.2597  18-May-20
# 1  193.9594        1.05%  10-May-21  193.9594  10-May-21  120.9285  18-May-20
# 2  245.7485        0.67%  10-May-21  254.4339  15-Feb-21  156.8961  18-May-20
# 3  231.0842        0.66%  10-May-21  239.7848  15-Feb-21  148.9459  18-May-20
# 4   97.6840         0.9%  10-May-21   99.9500  03-Mar-21   57.4770  19-May-20

# %% [markdown]
# ## Exctracting Focused Mutual Fund's SIP Returns Data
#
# Data in this table: Get absolute SIP returns. If 1Y column value is 10%, that means fund has given 10% returns on your SIP investments started 1 year back from latest NAV date.

# %%
focused_sip_rtns = pd.read_html(
    "https://www.moneycontrol.com/mutual-funds/performance-tracker/sip-returns/focused-fund.html")
df9 = pd.DataFrame(focused_sip_rtns[0])

# %%
#Renaming SIP returns column names
df9.rename({'1Y': '1Y_SIP_RTN(%)', '2Y': '2Y_SIP_RTN(%)', '3Y': '3Y_SIP_RTN(%)',
                  '5Y': '5Y_SIP_RTN(%)', '10Y': '10Y_SIP_RTN(%)', 'YTD' : 'YTD_SIP_RTN(%)'
           }, axis=1, inplace=True)

print("Shape of the dataframe:", df9.shape)
df9.head()
# Out:
# Shape of the dataframe: (44, 8)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0  Quant Focused Fund - Direct Plan - GrowthFocus...           -     12.12
# 1            Quant Focused Fund - GrowthFocused Fund           -     12.12
# 2  Nippon India Focused Equity Fund - Direct Plan...           5   4897.48
# 3  Nippon India Focused Equity Fund - GrowthFocus...           5   4897.48
# 4  Franklin India Focused Equity Fund - Direct - ...           3   7359.87
#
#   1Y_SIP_RTN(%) 2Y_SIP_RTN(%) 3Y_SIP_RTN(%) 5Y_SIP_RTN(%) 10Y_SIP_RTN(%)
# 0        43.55%        55.42%        58.62%        69.30%              -
# 1        41.86%        52.41%        54.66%        63.95%        170.41%
# 2        34.35%        41.41%        42.88%        53.51%              -
# 3        33.82%        40.40%        41.38%        47.45%        143.79%
# 4        33.51%        36.76%        39.73%        49.43%              -

# %%
df_final = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9],axis=1,sort=False)
print("Shape of the dataframe:", df_final.shape)
# Out:
# Shape of the dataframe: (50, 103)

# %%
# Remove duplicate columns by name in Pandas
df_final = df_final.loc[:,~df_final.columns.duplicated()]

# Removing spaces in the column names
#df_final.columns = df_final.columns.str.replace(' ','_')

print("Shape of the dataframe:", df_final.shape)
df_final.head()
# Out:
# Shape of the dataframe: (50, 84)
#                                          Scheme Name Crisil Rank  AuM (Cr)  \
# 0  Quant Focused Fund - Direct Plan - GrowthFocus...           -     12.12
# 1            Quant Focused Fund - GrowthFocused Fund           -     12.12
# 2  ICICI Prudential Focused Equity Fund - Direct ...           4   1316.11
# 3  ICICI Prudential Focused Equity Fund - Regular...           4   1316.11
# 4  Franklin India Focused Equity Fund - Direct - ...           3   7359.87
#
#   1W_RTN(%) 1M_RTN(%) 3M_RTN(%) 6M_RTN(%) YTD_RTN(%) 1Y_RTN(%) 2Y_RTN(%)  ...  \
# 0     5.35%     6.08%    18.97%    46.37%     26.48%    84.77%    29.83%  ...
# 1     5.24%     5.84%    18.30%    44.85%     25.52%    81.23%    27.71%  ...
# 2     3.55%     3.29%     2.77%    31.28%     14.42%    66.79%    19.13%  ...
# 3     3.54%     3.18%     2.48%    30.49%     13.92%    64.79%    17.84%  ...
# 4     2.94%     2.96%     1.83%    31.90%     16.62%    77.02%    17.74%  ...
#
#     NAV Date  52W High 52WH as on   52W Low 52WL as on 1Y_SIP_RTN(%)  \
# 0  10-May-21  209.4941  10-May-21  129.2597  18-May-20        43.55%
# 1  10-May-21  193.9594  10-May-21  120.9285  18-May-20        41.86%
# 2  10-May-21  254.4339  15-Feb-21  156.8961  18-May-20        34.35%
# 3  10-May-21  239.7848  15-Feb-21  148.9459  18-May-20        33.82%
# 4  10-May-21   99.9500  03-Mar-21   57.4770  19-May-20        33.51%
#
#   2Y_SIP_RTN(%) 3Y_SIP_RTN(%) 5Y_SIP_RTN(%) 10Y_SIP_RTN(%)
# 0        55.42%        58.62%        69.30%              -
# 1        52.41%        54.66%        63.95%        170.41%
# 2        41.41%        42.88%        53.51%              -
# 3        40.40%        41.38%        47.45%        143.79%
# 4        36.76%        39.73%        49.43%              -
#
# [5 rows x 84 columns]

# %%
#Exporting the consolidated elss mf data as a  csv file
#print("Shape of the dataframe:", df_final.shape)
#df_final.to_csv('focused_mf_data('+ str(pd.to_datetime('today').strftime('%d-%b-%Y %H:%M:%S')) + ').csv',
#               index=False)

#Exporting the elss mf data columns with its datatype as a  csv file
#df_dtypes.to_csv('elss_mf_col_data_types('+ str(pd.to_datetime('today').strftime('%d-%b-%Y %H:%M:%S')) + '.csv)')
